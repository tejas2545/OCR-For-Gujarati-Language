# %%
# -*- coding: utf-8 -*-
"""
Created on Sun Apr 21 13:09:10 2019

@author: dc
"""

import numpy as np
import pickle
import matplotlib.pyplot as plt
import os
import cv2
from tqdm import tqdm
import random
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
import keras

from sklearn.model_selection import train_test_split
from keras.utils import np_utils



CATEGORIES = sorted(list(os.listdir("/content/drive/MyDrive/OCR For Gujarati Language/Dataset/Gujarati Characters Dataset Photos/28x28")))
IMG_SIZE = 64
training_data = []


print(len(CATEGORIES))

IMG_SIZE = 64

#create training data

#%%
#create training data
training_data = []

def create_training_data(DATADIR):
    for category in CATEGORIES:
        path = os.path.join(DATADIR,category)  # create path to dataset
        class_num = CATEGORIES.index(category)

        for img in tqdm(os.listdir(path)):  # iterate over each image per alphbets
            try:
                img_array = cv2.imread(os.path.join(path,img) ,cv2.IMREAD_GRAYSCALE)  # convert to array
                img = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))  #size to normalize data size
                """for i in range(len(img)):
                    for j in range(len(img[0])):
                        img[i][j] = 255 - img[i][j]"""
                training_data.append([img, class_num])  # add this to our training_data
            except Exception as e:  # in the interest in keeping the output clean...
                pass
            #except OSError as e:
            #    print("OSErrroBad img most likely", e, os.path.join(path,img))
            #except Exception as e:
            #    print("general exception", e, os.path.join(path,img))
            
#loading data from dataset  folders
create_training_data("/content/drive/MyDrive/OCR For Gujarati Language/Dataset/Gujarati Characters Dataset Photos/28x28")

print(len(training_data))

pickle_out = open("GujaratiCharacters.pickle","wb")
pickle.dump(training_data, pickle_out)
pickle_out.close()

#loading data from pickle file
pickle_in = open("GujaratiCharacters.pickle","rb")
training_data = pickle.load(pickle_in)


#randomize data
random.shuffle(training_data)

X = []
Y = []

for features,label in training_data:
    X.append(features)
    Y.append(label)

#print(X[0].reshape(-1, IMG_SIZE, IMG_SIZE, 1))

X = np.array(X).reshape(-1, IMG_SIZE, IMG_SIZE, 1)

seed = 785
# split the data into training (50%) and testing (50%)
(X_train, X_test, Y_train, Y_test) = train_test_split(X, Y, test_size=0.20, random_state=seed)

X_train = X_train.reshape(X_train.shape[0], IMG_SIZE, IMG_SIZE, 1).astype('float32')
X_test = X_test.reshape(X_test.shape[0], IMG_SIZE, IMG_SIZE, 1).astype('float32')

X_train = X_train / 255
X_test = X_test / 255

# one hot encode outputs
Y_train = np_utils.to_categorical(Y_train)
Y_test = np_utils.to_categorical(Y_test)

num_classes = Y_test.shape[1]

#%%
#model training
model = Sequential()
model.add(Conv2D(32, (5, 5), input_shape=(IMG_SIZE, IMG_SIZE, 1), activation='relu'))
model.add(Conv2D(64, (3, 3), activation='relu'))
#model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
#model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Dropout(0.1))
model.add(Flatten())
#model.add(Dense(128, activation='relu'))
model.add(Dense(512, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))
# Compile model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
#%%

# Compile model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, Y_train, validation_data=(X_test, Y_test), epochs=200, batch_size=64, verbose=2)

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

#model evaluation
val_loss, val_acc = model.evaluate(X_test, Y_test)
print(val_loss)
print(val_acc)

#%%
#model evaluation
val_loss, val_acc = model.evaluate(X_test, Y_test)
print(val_loss)
print(val_acc)

#%%
# Visualizing the intermediate layer

#
from keras import backend as K
test_image = X_test[0:1]
print (test_image.shape)
def get_featuremaps(model, layer_idx, X_batch):
	get_activations = K.function([model.layers[0].input, K.learning_phase()],[model.layers[layer_idx].output,])
	activations = get_activations([X_batch,0])
	return activations

layer_num=4
filter_num=0

activations = get_featuremaps(model, int(layer_num),test_image)

print (np.shape(activations))
feature_maps = activations[0][0]      
print (np.shape(feature_maps))

if K.common.image_dim_ordering()=='th':
	feature_maps=np.rollaxis((np.rollaxis(feature_maps,2,0)),2,0)
print (feature_maps.shape)

fig=plt.figure(figsize=(16,16))
plt.imshow(feature_maps[:,:,filter_num],cmap='gray')
plt.savefig("featuremaps-layer-{}".format(layer_num) + "-filternum-{}".format(filter_num)+'.bmp')

num_of_featuremaps=feature_maps.shape[2]
fig=plt.figure(figsize=(16,16))	
plt.title("featuremaps-layer-{}".format(layer_num))
subplot_num=int(np.ceil(np.sqrt(num_of_featuremaps)))
for i in range(int(num_of_featuremaps)):
	ax = fig.add_subplot(subplot_num, subplot_num, i+1)
	#ax.imshow(output_image[0,:,:,i],interpolation='nearest' ) #to see the first filter
	ax.imshow(feature_maps[:,:,i],cmap='gray')
	plt.xticks([])
	plt.yticks([])
	plt.tight_layout()
plt.show()
fig.savefig("featuremaps-layer-{}".format(layer_num) + '.bmp')
#%%

#save the model
model.save('GujaratiCharacterModel')
#load saved model
new_model = tf.keras.models.load_model('GujaratiCharacterModel')

#predict image on test data
predictions = new_model.predict(X_test)

print(CATEGORIES[np.argmax(predictions[140])])

img = cv2.resize(X_test[160], (28,28))

plt.imshow(img)

keras.applications.vgg19.VGG19(include_top=True, weights='imagenet', input_tensor=None, input_shape=None, pooling=None, classes=1000)
# Out:
# 351
# 100%|██████████| 12/12 [00:00<00:00, 375.14it/s]
# 100%|██████████| 64/64 [00:00<00:00, 338.47it/s]
# 100%|██████████| 48/48 [00:00<00:00, 417.13it/s]
# 100%|██████████| 48/48 [00:00<00:00, 407.46it/s]
# 100%|██████████| 75/75 [00:00<00:00, 398.86it/s]
# 100%|██████████| 72/72 [00:00<00:00, 385.08it/s]
# 100%|██████████| 45/45 [00:00<00:00, 373.69it/s]
# 100%|██████████| 58/58 [00:00<00:00, 370.61it/s]
# 100%|██████████| 60/60 [00:00<00:00, 399.23it/s]
# 100%|██████████| 56/56 [00:00<00:00, 343.71it/s]
# 100%|██████████| 140/140 [00:00<00:00, 406.03it/s]
# 100%|██████████| 2/2 [00:00<00:00, 221.16it/s]
# 100%|██████████| 150/150 [00:00<00:00, 379.91it/s]
# 100%|██████████| 150/150 [00:00<00:00, 380.30it/s]
# 100%|██████████| 150/150 [00:00<00:00, 404.44it/s]
# 100%|██████████| 150/150 [00:00<00:00, 370.23it/s]
# 100%|██████████| 150/150 [00:00<00:00, 377.49it/s]
# 100%|██████████| 153/153 [00:00<00:00, 374.87it/s]
# 100%|██████████| 26/26 [00:00<00:00, 370.38it/s]
# 100%|██████████| 159/159 [00:00<00:00, 399.10it/s]
# 100%|██████████| 160/160 [00:00<00:00, 399.25it/s]
# 100%|██████████| 170/170 [00:00<00:00, 393.58it/s]
# 100%|██████████| 2/2 [00:00<00:00, 340.89it/s]
# 100%|██████████| 170/170 [00:00<00:00, 390.02it/s]
# 100%|██████████| 16/16 [00:00<00:00, 381.31it/s]
# 100%|██████████| 24/24 [00:00<00:00, 353.20it/s]
# 100%|██████████| 170/170 [00:00<00:00, 406.40it/s]
# 100%|██████████| 102/102 [00:00<00:00, 383.48it/s]
# 100%|██████████| 46/46 [00:00<00:00, 373.48it/s]
# 100%|██████████| 57/57 [00:00<00:00, 376.35it/s]
# 100%|██████████| 14/14 [00:00<00:00, 424.03it/s]
# 100%|██████████| 47/47 [00:00<00:00, 372.48it/s]
# 100%|██████████| 26/26 [00:00<00:00, 353.74it/s]
# 100%|██████████| 38/38 [00:00<00:00, 399.84it/s]
# 100%|██████████| 30/30 [00:00<00:00, 413.34it/s]
# 100%|██████████| 20/20 [00:00<00:00, 411.47it/s]
# 100%|██████████| 80/80 [00:00<00:00, 400.58it/s]
# 100%|██████████| 70/70 [00:00<00:00, 397.73it/s]
# 100%|██████████| 75/75 [00:00<00:00, 408.97it/s]
# 100%|██████████| 47/47 [00:00<00:00, 359.83it/s]
# 100%|██████████| 59/59 [00:00<00:00, 397.22it/s]
# 100%|██████████| 12/12 [00:00<00:00, 401.62it/s]
# 100%|██████████| 18/18 [00:00<00:00, 366.47it/s]
# 100%|██████████| 36/36 [00:00<00:00, 418.36it/s]
# 100%|██████████| 13/13 [00:00<00:00, 423.83it/s]
# 100%|██████████| 190/190 [00:00<00:00, 405.92it/s]
# 100%|██████████| 84/84 [00:00<00:00, 395.02it/s]
# 100%|██████████| 82/82 [00:00<00:00, 377.15it/s]
# 100%|██████████| 45/45 [00:00<00:00, 399.13it/s]
# 100%|██████████| 57/57 [00:00<00:00, 375.66it/s]
# 100%|██████████| 10/10 [00:00<00:00, 348.58it/s]
# 100%|██████████| 24/24 [00:00<00:00, 334.66it/s]
# 100%|██████████| 36/36 [00:00<00:00, 411.69it/s]
# 100%|██████████| 12/12 [00:00<00:00, 327.71it/s]
# 100%|██████████| 17/17 [00:00<00:00, 382.52it/s]
# 100%|██████████| 200/200 [00:00<00:00, 372.55it/s]
# 100%|██████████| 85/85 [00:00<00:00, 368.04it/s]
# 100%|██████████| 82/82 [00:00<00:00, 409.90it/s]
# 100%|██████████| 42/42 [00:00<00:00, 378.74it/s]
# 100%|██████████| 60/60 [00:00<00:00, 382.95it/s]
# 100%|██████████| 11/11 [00:00<00:00, 340.12it/s]
# 100%|██████████| 24/24 [00:00<00:00, 353.13it/s]
# 100%|██████████| 36/36 [00:00<00:00, 329.63it/s]
# 100%|██████████| 12/12 [00:00<00:00, 322.78it/s]
# 100%|██████████| 17/17 [00:00<00:00, 342.49it/s]
# 100%|██████████| 210/210 [00:00<00:00, 384.33it/s]
# 100%|██████████| 77/77 [00:00<00:00, 393.24it/s]
# 100%|██████████| 75/75 [00:00<00:00, 369.25it/s]
# 100%|██████████| 42/42 [00:00<00:00, 376.66it/s]
# 100%|██████████| 60/60 [00:00<00:00, 397.91it/s]
# 100%|██████████| 10/10 [00:00<00:00, 358.62it/s]
# 100%|██████████| 22/22 [00:00<00:00, 399.83it/s]
# 100%|██████████| 36/36 [00:00<00:00, 375.54it/s]
# 100%|██████████| 12/12 [00:00<00:00, 320.05it/s]
# 100%|██████████| 18/18 [00:00<00:00, 395.25it/s]
# 100%|██████████| 220/220 [00:00<00:00, 378.39it/s]
# 100%|██████████| 73/73 [00:00<00:00, 400.97it/s]
# 100%|██████████| 81/81 [00:00<00:00, 389.61it/s]
# 100%|██████████| 39/39 [00:00<00:00, 351.76it/s]
# 100%|██████████| 64/64 [00:00<00:00, 394.36it/s]
# 100%|██████████| 12/12 [00:00<00:00, 359.18it/s]
# 100%|██████████| 24/24 [00:00<00:00, 361.45it/s]
# 100%|██████████| 34/34 [00:00<00:00, 389.65it/s]
# 100%|██████████| 11/11 [00:00<00:00, 349.15it/s]
# 100%|██████████| 16/16 [00:00<00:00, 409.17it/s]
# 100%|██████████| 230/230 [00:00<00:00, 385.51it/s]
# 100%|██████████| 70/70 [00:00<00:00, 387.24it/s]
# 100%|██████████| 76/76 [00:00<00:00, 429.56it/s]
# 100%|██████████| 46/46 [00:00<00:00, 429.17it/s]
# 100%|██████████| 57/57 [00:00<00:00, 362.12it/s]
# 100%|██████████| 12/12 [00:00<00:00, 384.86it/s]
# 100%|██████████| 23/23 [00:00<00:00, 429.23it/s]
# 100%|██████████| 35/35 [00:00<00:00, 385.84it/s]
# 100%|██████████| 12/12 [00:00<00:00, 412.84it/s]
# 100%|██████████| 240/240 [00:00<00:00, 383.94it/s]
# 100%|██████████| 73/73 [00:00<00:00, 405.47it/s]
# 100%|██████████| 83/83 [00:00<00:00, 379.68it/s]
# 100%|██████████| 35/35 [00:00<00:00, 378.16it/s]
# 100%|██████████| 60/60 [00:00<00:00, 412.17it/s]
# 100%|██████████| 11/11 [00:00<00:00, 431.74it/s]
# 100%|██████████| 24/24 [00:00<00:00, 421.33it/s]
# 100%|██████████| 36/36 [00:00<00:00, 430.48it/s]
# 100%|██████████| 12/12 [00:00<00:00, 377.90it/s]
# 100%|██████████| 77/77 [00:00<00:00, 397.23it/s]
# 100%|██████████| 79/79 [00:00<00:00, 391.20it/s]
# 100%|██████████| 85/85 [00:00<00:00, 370.65it/s]
# 100%|██████████| 48/48 [00:00<00:00, 335.40it/s]
# 100%|██████████| 58/58 [00:00<00:00, 368.66it/s]
# 100%|██████████| 12/12 [00:00<00:00, 302.61it/s]
# 100%|██████████| 23/23 [00:00<00:00, 336.83it/s]
# 100%|██████████| 35/35 [00:00<00:00, 372.77it/s]
# 100%|██████████| 12/12 [00:00<00:00, 391.58it/s]
# 100%|██████████| 260/260 [00:00<00:00, 375.84it/s]
# 100%|██████████| 72/72 [00:00<00:00, 409.62it/s]
# 100%|██████████| 81/81 [00:00<00:00, 407.35it/s]
# 100%|██████████| 45/45 [00:00<00:00, 356.60it/s]
# 100%|██████████| 60/60 [00:00<00:00, 387.26it/s]
# 100%|██████████| 12/12 [00:00<00:00, 339.32it/s]
# 100%|██████████| 24/24 [00:00<00:00, 371.57it/s]
# 100%|██████████| 36/36 [00:00<00:00, 425.80it/s]
# 100%|██████████| 12/12 [00:00<00:00, 419.69it/s]
# 100%|██████████| 2/2 [00:00<00:00, 310.31it/s]
# 100%|██████████| 270/270 [00:00<00:00, 388.47it/s]
# 100%|██████████| 73/73 [00:00<00:00, 382.50it/s]
# 100%|██████████| 81/81 [00:00<00:00, 420.38it/s]
# 100%|██████████| 48/48 [00:00<00:00, 375.35it/s]
# 100%|██████████| 59/59 [00:00<00:00, 375.39it/s]
# 100%|██████████| 12/12 [00:00<00:00, 374.72it/s]
# 100%|██████████| 24/24 [00:00<00:00, 370.36it/s]
# 100%|██████████| 36/36 [00:00<00:00, 373.50it/s]
# 100%|██████████| 10/10 [00:00<00:00, 310.84it/s]
# 100%|██████████| 280/280 [00:00<00:00, 374.79it/s]
# 100%|██████████| 76/76 [00:00<00:00, 391.60it/s]
# 100%|██████████| 84/84 [00:00<00:00, 359.65it/s]
# 100%|██████████| 47/47 [00:00<00:00, 340.21it/s]
# 100%|██████████| 61/61 [00:00<00:00, 399.20it/s]
# 100%|██████████| 12/12 [00:00<00:00, 353.23it/s]
# 100%|██████████| 24/24 [00:00<00:00, 350.83it/s]
# 100%|██████████| 36/36 [00:00<00:00, 374.81it/s]
# 100%|██████████| 12/12 [00:00<00:00, 375.24it/s]
# 100%|██████████| 280/280 [00:00<00:00, 398.90it/s]
# 100%|██████████| 71/71 [00:00<00:00, 402.45it/s]
# 100%|██████████| 87/87 [00:00<00:00, 378.97it/s]
# 100%|██████████| 47/47 [00:00<00:00, 338.06it/s]
# 100%|██████████| 58/58 [00:00<00:00, 404.27it/s]
# 100%|██████████| 12/12 [00:00<00:00, 422.55it/s]
# 100%|██████████| 24/24 [00:00<00:00, 441.06it/s]
# 100%|██████████| 36/36 [00:00<00:00, 422.40it/s]
# 100%|██████████| 12/12 [00:00<00:00, 286.46it/s]
# 100%|██████████| 290/290 [00:00<00:00, 382.90it/s]
# 100%|██████████| 74/74 [00:00<00:00, 409.23it/s]
# 100%|██████████| 85/85 [00:00<00:00, 369.63it/s]
# 100%|██████████| 46/46 [00:00<00:00, 358.07it/s]
# 100%|██████████| 60/60 [00:00<00:00, 417.63it/s]
# 100%|██████████| 12/12 [00:00<00:00, 354.50it/s]
# 100%|██████████| 23/23 [00:00<00:00, 419.64it/s]
# 100%|██████████| 36/36 [00:00<00:00, 391.34it/s]
# 100%|██████████| 12/12 [00:00<00:00, 411.91it/s]
# 100%|██████████| 293/293 [00:00<00:00, 378.79it/s]
# 100%|██████████| 72/72 [00:00<00:00, 386.21it/s]
# 100%|██████████| 84/84 [00:00<00:00, 386.71it/s]
# 100%|██████████| 48/48 [00:00<00:00, 362.79it/s]
# 100%|██████████| 61/61 [00:00<00:00, 379.94it/s]
# 100%|██████████| 12/12 [00:00<00:00, 331.14it/s]
# 100%|██████████| 23/23 [00:00<00:00, 404.07it/s]
# 100%|██████████| 36/36 [00:00<00:00, 414.93it/s]
# 100%|██████████| 12/12 [00:00<00:00, 365.56it/s]
# 100%|██████████| 292/292 [00:00<00:00, 389.38it/s]
# 100%|██████████| 70/70 [00:00<00:00, 388.26it/s]
# 100%|██████████| 79/79 [00:00<00:00, 358.74it/s]
# 100%|██████████| 36/36 [00:00<00:00, 383.21it/s]
# 100%|██████████| 59/59 [00:00<00:00, 367.85it/s]
# 100%|██████████| 12/12 [00:00<00:00, 325.22it/s]
# 100%|██████████| 23/23 [00:00<00:00, 410.08it/s]
# 100%|██████████| 34/34 [00:00<00:00, 381.86it/s]
# 100%|██████████| 12/12 [00:00<00:00, 274.05it/s]
# 100%|██████████| 48/48 [00:00<00:00, 348.87it/s]
# 100%|██████████| 12/12 [00:00<00:00, 280.02it/s]
# 100%|██████████| 24/24 [00:00<00:00, 406.18it/s]
# 100%|██████████| 12/12 [00:00<00:00, 368.03it/s]
# 100%|██████████| 12/12 [00:00<00:00, 373.75it/s]
# 100%|██████████| 12/12 [00:00<00:00, 322.63it/s]
# 100%|██████████| 12/12 [00:00<00:00, 338.57it/s]
# 100%|██████████| 12/12 [00:00<00:00, 447.69it/s]
# 100%|██████████| 12/12 [00:00<00:00, 272.93it/s]
# 100%|██████████| 12/12 [00:00<00:00, 427.99it/s]
# 100%|██████████| 290/290 [00:00<00:00, 385.86it/s]
# 100%|██████████| 72/72 [00:00<00:00, 379.47it/s]
# 100%|██████████| 82/82 [00:00<00:00, 372.03it/s]
# 100%|██████████| 50/50 [00:00<00:00, 367.77it/s]
# 100%|██████████| 61/61 [00:00<00:00, 397.64it/s]
# 100%|██████████| 13/13 [00:00<00:00, 403.96it/s]
# 100%|██████████| 23/23 [00:00<00:00, 343.37it/s]
# 100%|██████████| 34/34 [00:00<00:00, 356.24it/s]
# 100%|██████████| 12/12 [00:00<00:00, 373.97it/s]
# 100%|██████████| 294/294 [00:00<00:00, 389.63it/s]
# 100%|██████████| 72/72 [00:00<00:00, 380.95it/s]
# 100%|██████████| 87/87 [00:00<00:00, 390.64it/s]
# 100%|██████████| 48/48 [00:00<00:00, 364.07it/s]
# 100%|██████████| 57/57 [00:00<00:00, 374.37it/s]
# 100%|██████████| 12/12 [00:00<00:00, 360.09it/s]
# 100%|██████████| 24/24 [00:00<00:00, 357.24it/s]
# 100%|██████████| 36/36 [00:00<00:00, 349.93it/s]
# 100%|██████████| 11/11 [00:00<00:00, 406.13it/s]
# 100%|██████████| 12/12 [00:00<00:00, 365.56it/s]
# 100%|██████████| 292/292 [00:00<00:00, 388.24it/s]
# 100%|██████████| 82/82 [00:00<00:00, 367.73it/s]
# 100%|██████████| 92/92 [00:00<00:00, 368.43it/s]
# 100%|██████████| 50/50 [00:00<00:00, 384.57it/s]
# 100%|██████████| 63/63 [00:00<00:00, 362.63it/s]
# 100%|██████████| 13/13 [00:00<00:00, 464.46it/s]
# 100%|██████████| 27/27 [00:00<00:00, 379.16it/s]
# 100%|██████████| 36/36 [00:00<00:00, 342.63it/s]
# 100%|██████████| 11/11 [00:00<00:00, 326.52it/s]
# 100%|██████████| 292/292 [00:00<00:00, 400.09it/s]
# 100%|██████████| 73/73 [00:00<00:00, 397.36it/s]
# 100%|██████████| 80/80 [00:00<00:00, 390.72it/s]
# 100%|██████████| 48/48 [00:00<00:00, 390.12it/s]
# 100%|██████████| 61/61 [00:00<00:00, 415.40it/s]
# 100%|██████████| 12/12 [00:00<00:00, 377.90it/s]
# 100%|██████████| 26/26 [00:00<00:00, 409.82it/s]
# 100%|██████████| 36/36 [00:00<00:00, 412.08it/s]
# 100%|██████████| 12/12 [00:00<00:00, 406.15it/s]
# 100%|██████████| 77/77 [00:00<00:00, 393.48it/s]
# 100%|██████████| 67/67 [00:00<00:00, 407.63it/s]
# 100%|██████████| 68/68 [00:00<00:00, 395.86it/s]
# 100%|██████████| 54/54 [00:00<00:00, 354.37it/s]
# 100%|██████████| 58/58 [00:00<00:00, 329.63it/s]
# 100%|██████████| 16/16 [00:00<00:00, 352.41it/s]
# 100%|██████████| 25/25 [00:00<00:00, 418.26it/s]
# 100%|██████████| 36/36 [00:00<00:00, 401.82it/s]
# 100%|██████████| 3/3 [00:00<00:00, 235.17it/s]
# 100%|██████████| 85/85 [00:00<00:00, 361.22it/s]
# 100%|██████████| 72/72 [00:00<00:00, 378.59it/s]
# 100%|██████████| 93/93 [00:00<00:00, 385.09it/s]
# 100%|██████████| 47/47 [00:00<00:00, 373.00it/s]
# 100%|██████████| 58/58 [00:00<00:00, 377.26it/s]
# 100%|██████████| 10/10 [00:00<00:00, 400.14it/s]
# 100%|██████████| 24/24 [00:00<00:00, 392.12it/s]
# 100%|██████████| 36/36 [00:00<00:00, 421.70it/s]
# 100%|██████████| 13/13 [00:00<00:00, 360.63it/s]
# 100%|██████████| 77/77 [00:00<00:00, 346.17it/s]
# 100%|██████████| 73/73 [00:00<00:00, 384.73it/s]
# 100%|██████████| 85/85 [00:00<00:00, 372.27it/s]
# 100%|██████████| 44/44 [00:00<00:00, 372.15it/s]
# 100%|██████████| 60/60 [00:00<00:00, 366.61it/s]
# 100%|██████████| 12/12 [00:00<00:00, 326.98it/s]
# 100%|██████████| 23/23 [00:00<00:00, 394.67it/s]
# 100%|██████████| 36/36 [00:00<00:00, 414.32it/s]
# 100%|██████████| 12/12 [00:00<00:00, 443.43it/s]
# 100%|██████████| 77/77 [00:00<00:00, 382.19it/s]
# 100%|██████████| 73/73 [00:00<00:00, 379.86it/s]
# 100%|██████████| 80/80 [00:00<00:00, 368.67it/s]
# 100%|██████████| 45/45 [00:00<00:00, 397.99it/s]
# 100%|██████████| 58/58 [00:00<00:00, 393.78it/s]
# 100%|██████████| 11/11 [00:00<00:00, 374.16it/s]
# 100%|██████████| 24/24 [00:00<00:00, 344.08it/s]
# 100%|██████████| 35/35 [00:00<00:00, 416.34it/s]
# 100%|██████████| 12/12 [00:00<00:00, 380.12it/s]
# 100%|██████████| 79/79 [00:00<00:00, 405.42it/s]
# 100%|██████████| 74/74 [00:00<00:00, 384.89it/s]
# 100%|██████████| 84/84 [00:00<00:00, 378.46it/s]
# 100%|██████████| 55/55 [00:00<00:00, 357.35it/s]
# 100%|██████████| 58/58 [00:00<00:00, 415.64it/s]
# 100%|██████████| 11/11 [00:00<00:00, 384.71it/s]
# 100%|██████████| 20/20 [00:00<00:00, 346.26it/s]
# 100%|██████████| 34/34 [00:00<00:00, 397.30it/s]
# 100%|██████████| 11/11 [00:00<00:00, 331.57it/s]
# 100%|██████████| 75/75 [00:00<00:00, 372.67it/s]
# 100%|██████████| 81/81 [00:00<00:00, 365.71it/s]
# 100%|██████████| 94/94 [00:00<00:00, 357.86it/s]
# 100%|██████████| 36/36 [00:00<00:00, 376.86it/s]
# 100%|██████████| 50/50 [00:00<00:00, 338.01it/s]
# 100%|██████████| 8/8 [00:00<00:00, 390.46it/s]
# 100%|██████████| 18/18 [00:00<00:00, 346.27it/s]
# 100%|██████████| 33/33 [00:00<00:00, 380.11it/s]
# 100%|██████████| 22/22 [00:00<00:00, 420.35it/s]
# 100%|██████████| 77/77 [00:00<00:00, 390.92it/s]
# 100%|██████████| 71/71 [00:00<00:00, 412.71it/s]
# 100%|██████████| 82/82 [00:00<00:00, 354.56it/s]
# 100%|██████████| 46/46 [00:00<00:00, 361.75it/s]
# 100%|██████████| 58/58 [00:00<00:00, 391.18it/s]
# 100%|██████████| 11/11 [00:00<00:00, 400.68it/s]
# 100%|██████████| 24/24 [00:00<00:00, 377.37it/s]
# 100%|██████████| 36/36 [00:00<00:00, 401.47it/s]
# 100%|██████████| 11/11 [00:00<00:00, 388.20it/s]
# 100%|██████████| 75/75 [00:00<00:00, 377.69it/s]
# 100%|██████████| 73/73 [00:00<00:00, 385.86it/s]
# 100%|██████████| 95/95 [00:00<00:00, 402.25it/s]
# 100%|██████████| 57/57 [00:00<00:00, 372.21it/s]
# 100%|██████████| 57/57 [00:00<00:00, 359.03it/s]
# 100%|██████████| 12/12 [00:00<00:00, 409.06it/s]
# 100%|██████████| 24/24 [00:00<00:00, 393.91it/s]
# 100%|██████████| 35/35 [00:00<00:00, 354.31it/s]
# 100%|██████████| 11/11 [00:00<00:00, 361.41it/s]
# 100%|██████████| 75/75 [00:00<00:00, 396.70it/s]
# 100%|██████████| 73/73 [00:00<00:00, 375.47it/s]
# 100%|██████████| 80/80 [00:00<00:00, 364.80it/s]
# 100%|██████████| 47/47 [00:00<00:00, 387.93it/s]
# 100%|██████████| 60/60 [00:00<00:00, 359.06it/s]
# 100%|██████████| 12/12 [00:00<00:00, 360.29it/s]
# 100%|██████████| 24/24 [00:00<00:00, 356.65it/s]
# 100%|██████████| 35/35 [00:00<00:00, 384.78it/s]
# 100%|██████████| 12/12 [00:00<00:00, 298.99it/s]
# 100%|██████████| 74/74 [00:00<00:00, 399.14it/s]
# 100%|██████████| 80/80 [00:00<00:00, 371.34it/s]
# 100%|██████████| 85/85 [00:00<00:00, 362.22it/s]
# 100%|██████████| 48/48 [00:00<00:00, 339.27it/s]
# 100%|██████████| 59/59 [00:00<00:00, 368.99it/s]
# 100%|██████████| 12/12 [00:00<00:00, 339.98it/s]
# 100%|██████████| 23/23 [00:00<00:00, 398.94it/s]
# 100%|██████████| 36/36 [00:00<00:00, 369.18it/s]
# 100%|██████████| 11/11 [00:00<00:00, 346.77it/s]
# 100%|██████████| 76/76 [00:00<00:00, 405.88it/s]
# 100%|██████████| 76/76 [00:00<00:00, 394.28it/s]
# 100%|██████████| 83/83 [00:00<00:00, 380.87it/s]
# 100%|██████████| 48/48 [00:00<00:00, 347.33it/s]
# 100%|██████████| 59/59 [00:00<00:00, 368.96it/s]
# 100%|██████████| 12/12 [00:00<00:00, 341.64it/s]
# 100%|██████████| 28/28 [00:00<00:00, 354.69it/s]
# 100%|██████████| 35/35 [00:00<00:00, 352.86it/s]
# 100%|██████████| 11/11 [00:00<00:00, 360.39it/s]
# 100%|██████████| 11/11 [00:00<00:00, 379.69it/s]
# 100%|██████████| 1/1 [00:00<00:00, 238.14it/s]
# 100%|██████████| 84/84 [00:00<00:00, 373.26it/s]
# 100%|██████████| 73/73 [00:00<00:00, 398.41it/s]
# 100%|██████████| 80/80 [00:00<00:00, 370.72it/s]
# 100%|██████████| 47/47 [00:00<00:00, 384.90it/s]
# 100%|██████████| 49/49 [00:00<00:00, 384.39it/s]
# 100%|██████████| 12/12 [00:00<00:00, 388.45it/s]
# 100%|██████████| 25/25 [00:00<00:00, 389.59it/s]
# 100%|██████████| 37/37 [00:00<00:00, 331.37it/s]
# 100%|██████████| 12/12 [00:00<00:00, 315.28it/s]
# 100%|██████████| 77/77 [00:00<00:00, 347.53it/s]
# 100%|██████████| 72/72 [00:00<00:00, 399.79it/s]
# 100%|██████████| 85/85 [00:00<00:00, 370.58it/s]
# 100%|██████████| 47/47 [00:00<00:00, 351.08it/s]
# 100%|██████████| 62/62 [00:00<00:00, 360.51it/s]
# 100%|██████████| 12/12 [00:00<00:00, 326.09it/s]
# 100%|██████████| 24/24 [00:00<00:00, 404.46it/s]
# 100%|██████████| 35/35 [00:00<00:00, 398.78it/s]
# 100%|██████████| 12/12 [00:00<00:00, 347.60it/s]
# 100%|██████████| 74/74 [00:00<00:00, 395.37it/s]
# 100%|██████████| 70/70 [00:00<00:00, 382.45it/s]
# 100%|██████████| 61/61 [00:00<00:00, 378.55it/s]
# 100%|██████████| 48/48 [00:00<00:00, 358.92it/s]
# 100%|██████████| 57/57 [00:00<00:00, 364.51it/s]
# 100%|██████████| 9/9 [00:00<00:00, 306.33it/s]
# 100%|██████████| 16/16 [00:00<00:00, 329.62it/s]
# 100%|██████████| 34/34 [00:00<00:00, 371.69it/s]
# 100%|██████████| 10/10 [00:00<00:00, 348.01it/s]
# 20119
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 60, 60, 32)        832
#
#  conv2d_5 (Conv2D)           (None, 58, 58, 64)        18496
#
#  max_pooling2d_3 (MaxPooling  (None, 29, 29, 64)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 27, 27, 64)        36928
#
#  max_pooling2d_4 (MaxPooling  (None, 13, 13, 64)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 11, 11, 128)       73856
#
#  max_pooling2d_5 (MaxPooling  (None, 5, 5, 128)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 5, 5, 128)         0
#
#  flatten_1 (Flatten)         (None, 3200)              0
#
#  dense_2 (Dense)             (None, 512)               1638912
#
#  dense_3 (Dense)             (None, 351)               180063
#
# =================================================================
# Total params: 1,949,087
# Trainable params: 1,949,087
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 252/252 - 289s - loss: 4.6774 - accuracy: 0.1092 - val_loss: 3.7371 - val_accuracy: 0.2311 - 289s/epoch - 1s/step
# Epoch 2/200
# 252/252 - 289s - loss: 3.0084 - accuracy: 0.3223 - val_loss: 2.6777 - val_accuracy: 0.3683 - 289s/epoch - 1s/step
# Epoch 3/200
# 252/252 - 288s - loss: 2.0208 - accuracy: 0.4849 - val_loss: 2.3050 - val_accuracy: 0.4438 - 288s/epoch - 1s/step
# Epoch 4/200
# 252/252 - 287s - loss: 1.4020 - accuracy: 0.6118 - val_loss: 2.1978 - val_accuracy: 0.4925 - 287s/epoch - 1s/step
# Epoch 5/200
# 252/252 - 286s - loss: 0.9590 - accuracy: 0.7178 - val_loss: 2.2046 - val_accuracy: 0.5149 - 286s/epoch - 1s/step
# Epoch 6/200
# 252/252 - 286s - loss: 0.6328 - accuracy: 0.8075 - val_loss: 2.3554 - val_accuracy: 0.4943 - 286s/epoch - 1s/step
# Epoch 7/200
# 252/252 - 286s - loss: 0.4335 - accuracy: 0.8627 - val_loss: 2.6744 - val_accuracy: 0.5117 - 286s/epoch - 1s/step
# Epoch 8/200
# 252/252 - 286s - loss: 0.3050 - accuracy: 0.9025 - val_loss: 3.0756 - val_accuracy: 0.5244 - 286s/epoch - 1s/step
# Epoch 9/200
# 252/252 - 285s - loss: 0.2337 - accuracy: 0.9242 - val_loss: 3.3535 - val_accuracy: 0.5094 - 285s/epoch - 1s/step
# Epoch 10/200
# 252/252 - 286s - loss: 0.1951 - accuracy: 0.9366 - val_loss: 3.5094 - val_accuracy: 0.5199 - 286s/epoch - 1s/step
# Epoch 11/200
# 252/252 - 285s - loss: 0.1677 - accuracy: 0.9472 - val_loss: 3.6406 - val_accuracy: 0.5236 - 285s/epoch - 1s/step
# Epoch 12/200
# 252/252 - 286s - loss: 0.1403 - accuracy: 0.9550 - val_loss: 3.6280 - val_accuracy: 0.5224 - 286s/epoch - 1s/step
# Epoch 13/200
# 252/252 - 286s - loss: 0.1300 - accuracy: 0.9572 - val_loss: 3.9888 - val_accuracy: 0.5132 - 286s/epoch - 1s/step
# Epoch 14/200
# 252/252 - 285s - loss: 0.1166 - accuracy: 0.9650 - val_loss: 3.8773 - val_accuracy: 0.5298 - 285s/epoch - 1s/step
# Epoch 15/200
# 252/252 - 285s - loss: 0.0970 - accuracy: 0.9696 - val_loss: 3.9981 - val_accuracy: 0.5241 - 285s/epoch - 1s/step
# Epoch 16/200
# 252/252 - 285s - loss: 0.1048 - accuracy: 0.9660 - val_loss: 4.1048 - val_accuracy: 0.5306 - 285s/epoch - 1s/step
# Epoch 17/200
# 252/252 - 285s - loss: 0.0867 - accuracy: 0.9724 - val_loss: 4.2065 - val_accuracy: 0.5194 - 285s/epoch - 1s/step
# Epoch 18/200
# 252/252 - 285s - loss: 0.1056 - accuracy: 0.9660 - val_loss: 4.0579 - val_accuracy: 0.5281 - 285s/epoch - 1s/step
# Epoch 19/200
# 252/252 - 285s - loss: 0.0720 - accuracy: 0.9776 - val_loss: 4.2402 - val_accuracy: 0.5216 - 285s/epoch - 1s/step
# Epoch 20/200
# 252/252 - 285s - loss: 0.0769 - accuracy: 0.9757 - val_loss: 4.2239 - val_accuracy: 0.5318 - 285s/epoch - 1s/step
# Epoch 21/200
# 252/252 - 286s - loss: 0.0806 - accuracy: 0.9753 - val_loss: 4.0264 - val_accuracy: 0.5286 - 286s/epoch - 1s/step
# Epoch 22/200
# 252/252 - 285s - loss: 0.0832 - accuracy: 0.9730 - val_loss: 4.0344 - val_accuracy: 0.5303 - 285s/epoch - 1s/step
# Epoch 23/200
# 252/252 - 285s - loss: 0.0619 - accuracy: 0.9809 - val_loss: 4.5440 - val_accuracy: 0.5186 - 285s/epoch - 1s/step
# Epoch 24/200
# 252/252 - 285s - loss: 0.0665 - accuracy: 0.9797 - val_loss: 4.5862 - val_accuracy: 0.5321 - 285s/epoch - 1s/step
# Epoch 25/200
# 252/252 - 286s - loss: 0.0643 - accuracy: 0.9796 - val_loss: 4.1276 - val_accuracy: 0.5244 - 286s/epoch - 1s/step
# Epoch 26/200
# 252/252 - 286s - loss: 0.0661 - accuracy: 0.9794 - val_loss: 3.9408 - val_accuracy: 0.5256 - 286s/epoch - 1s/step
# Epoch 27/200
# 252/252 - 285s - loss: 0.0631 - accuracy: 0.9815 - val_loss: 4.2584 - val_accuracy: 0.5400 - 285s/epoch - 1s/step
# Epoch 28/200
# 252/252 - 285s - loss: 0.0590 - accuracy: 0.9819 - val_loss: 4.5698 - val_accuracy: 0.5328 - 285s/epoch - 1s/step
# Epoch 29/200
# 252/252 - 285s - loss: 0.0565 - accuracy: 0.9827 - val_loss: 4.4087 - val_accuracy: 0.5328 - 285s/epoch - 1s/step
# Epoch 30/200
# 252/252 - 285s - loss: 0.0635 - accuracy: 0.9804 - val_loss: 4.2108 - val_accuracy: 0.5281 - 285s/epoch - 1s/step
# Epoch 31/200
# 252/252 - 285s - loss: 0.0658 - accuracy: 0.9793 - val_loss: 4.2376 - val_accuracy: 0.5144 - 285s/epoch - 1s/step
# Epoch 32/200
# 252/252 - 285s - loss: 0.0561 - accuracy: 0.9820 - val_loss: 4.1266 - val_accuracy: 0.5306 - 285s/epoch - 1s/step
# Epoch 33/200
# 252/252 - 284s - loss: 0.0462 - accuracy: 0.9854 - val_loss: 4.3886 - val_accuracy: 0.5291 - 284s/epoch - 1s/step
# Epoch 34/200
# 252/252 - 285s - loss: 0.0425 - accuracy: 0.9868 - val_loss: 4.3079 - val_accuracy: 0.5328 - 285s/epoch - 1s/step
# Epoch 35/200
# 252/252 - 284s - loss: 0.0355 - accuracy: 0.9889 - val_loss: 4.5926 - val_accuracy: 0.5301 - 284s/epoch - 1s/step
# Epoch 36/200
# 252/252 - 284s - loss: 0.0482 - accuracy: 0.9856 - val_loss: 4.5958 - val_accuracy: 0.5234 - 284s/epoch - 1s/step
# Epoch 37/200
# 252/252 - 285s - loss: 0.0567 - accuracy: 0.9827 - val_loss: 3.8984 - val_accuracy: 0.5331 - 285s/epoch - 1s/step
# Epoch 38/200
# 252/252 - 285s - loss: 0.0417 - accuracy: 0.9862 - val_loss: 4.9837 - val_accuracy: 0.5201 - 285s/epoch - 1s/step
# Epoch 39/200
# 252/252 - 285s - loss: 0.0471 - accuracy: 0.9858 - val_loss: 4.3020 - val_accuracy: 0.5363 - 285s/epoch - 1s/step
# Epoch 40/200
# 252/252 - 285s - loss: 0.0467 - accuracy: 0.9855 - val_loss: 4.2890 - val_accuracy: 0.5221 - 285s/epoch - 1s/step
# Epoch 41/200
# 252/252 - 285s - loss: 0.0318 - accuracy: 0.9892 - val_loss: 4.5971 - val_accuracy: 0.5340 - 285s/epoch - 1s/step
# Epoch 42/200
# 252/252 - 285s - loss: 0.0352 - accuracy: 0.9891 - val_loss: 4.6546 - val_accuracy: 0.5271 - 285s/epoch - 1s/step
# Epoch 43/200
# 252/252 - 286s - loss: 0.0435 - accuracy: 0.9868 - val_loss: 5.0795 - val_accuracy: 0.5251 - 286s/epoch - 1s/step
# Epoch 44/200
# 252/252 - 286s - loss: 0.0375 - accuracy: 0.9889 - val_loss: 4.5405 - val_accuracy: 0.5321 - 286s/epoch - 1s/step
# Epoch 45/200
# 252/252 - 285s - loss: 0.0451 - accuracy: 0.9865 - val_loss: 4.6232 - val_accuracy: 0.5326 - 285s/epoch - 1s/step
# Epoch 46/200
# 252/252 - 285s - loss: 0.0320 - accuracy: 0.9889 - val_loss: 4.8217 - val_accuracy: 0.5435 - 285s/epoch - 1s/step
# Epoch 47/200
# 252/252 - 285s - loss: 0.0391 - accuracy: 0.9879 - val_loss: 4.5848 - val_accuracy: 0.5457 - 285s/epoch - 1s/step
# Epoch 48/200
# 252/252 - 285s - loss: 0.0340 - accuracy: 0.9911 - val_loss: 4.7492 - val_accuracy: 0.5353 - 285s/epoch - 1s/step
# Epoch 49/200
# 252/252 - 285s - loss: 0.0328 - accuracy: 0.9901 - val_loss: 4.7696 - val_accuracy: 0.5236 - 285s/epoch - 1s/step
# Epoch 50/200
# 252/252 - 286s - loss: 0.0356 - accuracy: 0.9894 - val_loss: 4.6932 - val_accuracy: 0.5286 - 286s/epoch - 1s/step
# Epoch 51/200
# 252/252 - 285s - loss: 0.0328 - accuracy: 0.9884 - val_loss: 4.6024 - val_accuracy: 0.5375 - 285s/epoch - 1s/step
# Epoch 52/200
# 252/252 - 284s - loss: 0.0397 - accuracy: 0.9877 - val_loss: 4.7616 - val_accuracy: 0.5343 - 284s/epoch - 1s/step
# Epoch 53/200
# 252/252 - 284s - loss: 0.0344 - accuracy: 0.9896 - val_loss: 4.6576 - val_accuracy: 0.5440 - 284s/epoch - 1s/step
# Epoch 54/200
# 252/252 - 286s - loss: 0.0231 - accuracy: 0.9932 - val_loss: 5.0015 - val_accuracy: 0.5358 - 286s/epoch - 1s/step
# Epoch 55/200
# 252/252 - 285s - loss: 0.0380 - accuracy: 0.9887 - val_loss: 4.6376 - val_accuracy: 0.5363 - 285s/epoch - 1s/step
# Epoch 56/200
# 252/252 - 285s - loss: 0.0301 - accuracy: 0.9899 - val_loss: 5.1323 - val_accuracy: 0.5390 - 285s/epoch - 1s/step
# Epoch 57/200
# 252/252 - 285s - loss: 0.0386 - accuracy: 0.9887 - val_loss: 4.6937 - val_accuracy: 0.5288 - 285s/epoch - 1s/step
# Epoch 58/200
# 252/252 - 285s - loss: 0.0313 - accuracy: 0.9904 - val_loss: 4.8108 - val_accuracy: 0.5350 - 285s/epoch - 1s/step
# Epoch 59/200
# 252/252 - 284s - loss: 0.0254 - accuracy: 0.9917 - val_loss: 5.1115 - val_accuracy: 0.5358 - 284s/epoch - 1s/step
# Epoch 60/200
# 252/252 - 284s - loss: 0.0262 - accuracy: 0.9925 - val_loss: 4.7197 - val_accuracy: 0.5417 - 284s/epoch - 1s/step
# Epoch 61/200
# 252/252 - 284s - loss: 0.0260 - accuracy: 0.9923 - val_loss: 4.8164 - val_accuracy: 0.5301 - 284s/epoch - 1s/step
# Epoch 62/200
# 252/252 - 285s - loss: 0.0308 - accuracy: 0.9895 - val_loss: 5.3325 - val_accuracy: 0.5447 - 285s/epoch - 1s/step
# Epoch 63/200
# 252/252 - 285s - loss: 0.0320 - accuracy: 0.9909 - val_loss: 4.4166 - val_accuracy: 0.5350 - 285s/epoch - 1s/step
# Epoch 64/200
# 252/252 - 285s - loss: 0.0253 - accuracy: 0.9917 - val_loss: 5.1974 - val_accuracy: 0.5375 - 285s/epoch - 1s/step
# Epoch 65/200

# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt
import os
import cv2
from tqdm import tqdm
import random
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D

from sklearn.model_selection import train_test_split
from keras.utils import np_utils

print(tf.__version__)
CATEGORIES = sorted(list(os.listdir("/content/drive/MyDrive/OCR For Gujarati Language/Dataset/Gujarati Characters Dataset Photos/28x28")))
IMG_SIZE = 64
training_data = []



CATEGORIES 

print(len(CATEGORIES))

IMG_SIZE = 28

#%%
#create training data
training_data = []

def create_training_data(DATADIR):
    for category in CATEGORIES:
        path = os.path.join(DATADIR,category)  # create path to dataset
        class_num = CATEGORIES.index(category)

        for img in tqdm(os.listdir(path)):  # iterate over each image per alphbets
            try:
                img_array = cv2.imread(os.path.join(path,img) ,cv2.IMREAD_GRAYSCALE)  # convert to array
                img = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))  #size to normalize data size
                """for i in range(len(img)):
                    for j in range(len(img[0])):
                        img[i][j] = 255 - img[i][j]"""
                training_data.append([img, class_num])  # add this to our training_data
            except Exception as e:  # in the interest in keeping the output clean...
                pass
            #except OSError as e:
            #    print("OSErrroBad img most likely", e, os.path.join(path,img))
            #except Exception as e:
            #    print("general exception", e, os.path.join(path,img))
            
#loading data from dataset  folders
create_training_data("/content/drive/MyDrive/OCR For Gujarati Language/Dataset/Gujarati Characters Dataset Photos/28x28")

pickle_out = open("GujaratiData.pickle","wb")
pickle.dump(training_data, pickle_out)
pickle_out.close()

#loading data from pickle file
pickle_in = open("GujaratiData.pickle","rb")
training_data = pickle.load(pickle_in)

print(training_data[0][0].shape)


#randomize data
random.shuffle(training_data)
for sample in training_data[:10]:
    print(sample[1])

X = []
Y = []

for features,label in training_data:
    X.append(features)
    Y.append(label)

#print(X[0].reshape(-1, IMG_SIZE, IMG_SIZE, 1))

X = np.array(X).reshape(-1, IMG_SIZE, IMG_SIZE)
Y = np.array(Y).reshape(X.shape[0],)

seed = 785

# split the data into training (80%) and testing (20%)
(X_train, X_test, Y_train, Y_test) = train_test_split(X, Y, test_size=0.20, random_state=seed)
print(Y[1])

X_train = X_train.reshape(X_train.shape[0], IMG_SIZE, IMG_SIZE, 1).astype('float32')
X_test = X_test.reshape(X_test.shape[0], IMG_SIZE, IMG_SIZE, 1).astype('float32')

X_train = X_train / 255
X_test = X_test / 255

# one hot encode outputs
Y_train = np_utils.to_categorical(Y_train)
Y_test = np_utils.to_categorical(Y_test)

num_classes = Y_test.shape[1]

plt.imshow((tf.squeeze(X_train[0])))
X_train[0].shape

#%%
#model training
model = Sequential()
       
model.add(Conv2D(filters=32, kernel_size=3, input_shape=(IMG_SIZE,IMG_SIZE,1), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Flatten())
model.add(Dense(units=100))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))
        
       
        
# Compile model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
#%%
history = model.fit(X_train, Y_train, validation_data=(X_test, Y_test), epochs=200, batch_size=64, verbose=2)


# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

#%%
#model evaluation
val_loss, val_acc = model.evaluate(X_test, Y_test)
print(val_loss)
print(val_acc)


#%%
# Visualizing the intermediate layer

#
from keras import backend as K
test_image = X_test[0:1]
print (test_image.shape)
def get_featuremaps(model, layer_idx, X_batch):
	get_activations = K.function([model.layers[0].input, K.learning_phase()],[model.layers[layer_idx].output,])
	activations = get_activations([X_batch,0])
	return activations

layer_num=0
filter_num=0

activations = get_featuremaps(model, int(layer_num),test_image)

print (np.shape(activations))
feature_maps = activations[0][0]      
print (np.shape(feature_maps))

if K.common.image_dim_ordering()=='th':
	feature_maps=np.rollaxis((np.rollaxis(feature_maps,2,0)),2,0)
print (feature_maps.shape)

fig=plt.figure(figsize=(16,16))
plt.imshow(feature_maps[:,:,filter_num],cmap='gray')
# plt.savefig("featuremaps-layer-{}".format(layer_num) + "-filternum-{}".format(filter_num)+'.bmp')

num_of_featuremaps=feature_maps.shape[2]
fig=plt.figure(figsize=(16,16))	
plt.title("featuremaps-layer-{}".format(layer_num))
subplot_num=int(np.ceil(np.sqrt(num_of_featuremaps)))
for i in range(int(num_of_featuremaps)):
	ax = fig.add_subplot(subplot_num, subplot_num, i+1)
	#ax.imshow(output_image[0,:,:,i],interpolation='nearest' ) #to see the first filter
	ax.imshow(feature_maps[:,:,i],cmap='gray')
	plt.xticks([])
	plt.yticks([])
	plt.tight_layout()
plt.show()
# fig.savefig("featuremaps-layer-{}".format(layer_num) + '.bmp')



# Printing the confusion matrix
from sklearn.metrics import classification_report,confusion_matrix
import itertools

Y_pred = model.predict(X_test)
print(Y_pred)
y_pred = np.argmax(Y_pred, axis=1)
print(y_pred)
#y_pred = model.predict_classes(X_test)
#print(y_pred)
#target_names = ['class 0(cats)', 'class 1(Dogs)', 'class 2(Horses)','class 3(Humans)']
					
print(classification_report(np.argmax(y_test,axis=1), y_pred,target_names=CATEGORIES))

print(confusion_matrix(np.argmax(y_test,axis=1), y_pred))


# Plotting the confusion matrix
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# Compute confusion matrix
cnf_matrix = (confusion_matrix(np.argmax(y_test,axis=1), y_pred))

np.set_printoptions(precision=2)

plt.figure()


plt.show()
#save the model
model.save('GujaratiOCRModel')
#load saved model
new_model = tf.keras.models.load_model('GujaratiOCRModel')

#predict image on test data
predictions = new_model.predict(X_test)

print(CATEGORIES[np.argmax(predictions[160])])

img = cv2.resize(X_test[160], (28,28))

plt.imshow(img)
# Out:
# 2.7.0
# 351
# 100%|██████████| 12/12 [00:02<00:00,  4.12it/s]
# 100%|██████████| 64/64 [00:15<00:00,  4.04it/s]
# 100%|██████████| 48/48 [00:12<00:00,  3.81it/s]
# 100%|██████████| 48/48 [00:12<00:00,  3.94it/s]
# 100%|██████████| 75/75 [00:17<00:00,  4.18it/s]
# 100%|██████████| 72/72 [00:16<00:00,  4.28it/s]
# 100%|██████████| 45/45 [00:09<00:00,  4.80it/s]
# 100%|██████████| 58/58 [00:13<00:00,  4.18it/s]
# 100%|██████████| 60/60 [00:14<00:00,  4.12it/s]
# 100%|██████████| 56/56 [00:13<00:00,  4.19it/s]
# 100%|██████████| 140/140 [00:33<00:00,  4.20it/s]
# 100%|██████████| 2/2 [00:00<00:00,  3.03it/s]
# 100%|██████████| 150/150 [00:34<00:00,  4.31it/s]
# 100%|██████████| 150/150 [00:34<00:00,  4.34it/s]
# 100%|██████████| 150/150 [00:33<00:00,  4.42it/s]
# 100%|██████████| 150/150 [00:35<00:00,  4.17it/s]
# 100%|██████████| 150/150 [00:35<00:00,  4.20it/s]
# 100%|██████████| 153/153 [00:36<00:00,  4.22it/s]
# 100%|██████████| 26/26 [00:06<00:00,  4.18it/s]
# 100%|██████████| 159/159 [00:37<00:00,  4.29it/s]
# 100%|██████████| 160/160 [00:37<00:00,  4.32it/s]
# 100%|██████████| 170/170 [00:38<00:00,  4.43it/s]
# 100%|██████████| 2/2 [00:00<00:00,  3.90it/s]
# 100%|██████████| 170/170 [00:40<00:00,  4.22it/s]
# 100%|██████████| 16/16 [00:04<00:00,  3.99it/s]
# 100%|██████████| 24/24 [00:05<00:00,  4.28it/s]
# 100%|██████████| 170/170 [00:38<00:00,  4.44it/s]
# 100%|██████████| 102/102 [00:24<00:00,  4.22it/s]
# 100%|██████████| 46/46 [00:10<00:00,  4.26it/s]
# 100%|██████████| 57/57 [00:13<00:00,  4.26it/s]
# 100%|██████████| 14/14 [00:03<00:00,  4.33it/s]
# 100%|██████████| 47/47 [00:10<00:00,  4.43it/s]
# 100%|██████████| 26/26 [00:05<00:00,  4.60it/s]
# 100%|██████████| 38/38 [00:08<00:00,  4.34it/s]
# 100%|██████████| 30/30 [00:06<00:00,  4.43it/s]
# 100%|██████████| 20/20 [00:04<00:00,  4.53it/s]
# 100%|██████████| 80/80 [00:18<00:00,  4.34it/s]
# 100%|██████████| 70/70 [00:16<00:00,  4.16it/s]
# 100%|██████████| 75/75 [00:18<00:00,  4.16it/s]
# 100%|██████████| 47/47 [00:10<00:00,  4.36it/s]
# 100%|██████████| 59/59 [00:13<00:00,  4.34it/s]
# 100%|██████████| 12/12 [00:02<00:00,  4.50it/s]
# 100%|██████████| 18/18 [00:04<00:00,  4.24it/s]
# 100%|██████████| 36/36 [00:07<00:00,  4.70it/s]
# 100%|██████████| 13/13 [00:03<00:00,  4.13it/s]
# 100%|██████████| 190/190 [00:44<00:00,  4.26it/s]
# 100%|██████████| 84/84 [00:17<00:00,  4.79it/s]
# 100%|██████████| 82/82 [00:18<00:00,  4.42it/s]
# 100%|██████████| 45/45 [00:10<00:00,  4.35it/s]
# 100%|██████████| 57/57 [00:12<00:00,  4.42it/s]
# 100%|██████████| 10/10 [00:02<00:00,  4.92it/s]
# 100%|██████████| 24/24 [00:06<00:00,  3.96it/s]
# 100%|██████████| 36/36 [00:08<00:00,  4.22it/s]
# 100%|██████████| 12/12 [00:02<00:00,  4.77it/s]
# 100%|██████████| 17/17 [00:03<00:00,  4.38it/s]
# 100%|██████████| 200/200 [00:46<00:00,  4.31it/s]
# 100%|██████████| 85/85 [00:19<00:00,  4.46it/s]
# 100%|██████████| 82/82 [00:19<00:00,  4.28it/s]
# 100%|██████████| 42/42 [00:09<00:00,  4.30it/s]
# 100%|██████████| 60/60 [00:13<00:00,  4.44it/s]
# 100%|██████████| 11/11 [00:02<00:00,  4.42it/s]
# 100%|██████████| 24/24 [00:05<00:00,  4.28it/s]
# 100%|██████████| 36/36 [00:08<00:00,  4.29it/s]
# 100%|██████████| 12/12 [00:02<00:00,  4.09it/s]
# 100%|██████████| 17/17 [00:04<00:00,  4.03it/s]
# 100%|██████████| 210/210 [00:48<00:00,  4.30it/s]
# 100%|██████████| 77/77 [00:16<00:00,  4.69it/s]
# 100%|██████████| 75/75 [00:17<00:00,  4.17it/s]
# 100%|██████████| 42/42 [00:09<00:00,  4.32it/s]
# 100%|██████████| 60/60 [00:12<00:00,  4.70it/s]
# 100%|██████████| 10/10 [00:02<00:00,  4.43it/s]
# 100%|██████████| 22/22 [00:04<00:00,  4.89it/s]
# 100%|██████████| 36/36 [00:08<00:00,  4.19it/s]
# 100%|██████████| 12/12 [00:02<00:00,  4.58it/s]
# 100%|██████████| 18/18 [00:04<00:00,  4.25it/s]
# 100%|██████████| 220/220 [00:50<00:00,  4.31it/s]
# 100%|██████████| 73/73 [00:16<00:00,  4.42it/s]
# 100%|██████████| 81/81 [00:18<00:00,  4.41it/s]
# 100%|██████████| 39/39 [00:08<00:00,  4.36it/s]
# 100%|██████████| 64/64 [00:15<00:00,  4.06it/s]
# 100%|██████████| 12/12 [00:02<00:00,  4.73it/s]
# 100%|██████████| 24/24 [00:05<00:00,  4.73it/s]
# 100%|██████████| 34/34 [00:07<00:00,  4.59it/s]
# 100%|██████████| 11/11 [00:02<00:00,  3.87it/s]
# 100%|██████████| 16/16 [00:03<00:00,  4.08it/s]
# 100%|██████████| 230/230 [00:53<00:00,  4.30it/s]
# 100%|██████████| 70/70 [00:16<00:00,  4.26it/s]
# 100%|██████████| 76/76 [00:19<00:00,  3.93it/s]
# 100%|██████████| 46/46 [00:10<00:00,  4.19it/s]
# 100%|██████████| 57/57 [00:13<00:00,  4.15it/s]
# 100%|██████████| 12/12 [00:02<00:00,  4.09it/s]
# 100%|██████████| 23/23 [00:05<00:00,  4.54it/s]
# 100%|██████████| 35/35 [00:08<00:00,  4.30it/s]
# 100%|██████████| 12/12 [00:02<00:00,  4.76it/s]
# 100%|██████████| 240/240 [00:55<00:00,  4.32it/s]
# 100%|██████████| 73/73 [00:16<00:00,  4.46it/s]
# 100%|██████████| 83/83 [00:19<00:00,  4.24it/s]
# 100%|██████████| 35/35 [00:07<00:00,  4.45it/s]
# 100%|██████████| 60/60 [00:14<00:00,  4.14it/s]
# 100%|██████████| 11/11 [00:02<00:00,  3.74it/s]
# 100%|██████████| 24/24 [00:05<00:00,  4.26it/s]
# 100%|██████████| 36/36 [00:08<00:00,  4.38it/s]
# 100%|██████████| 12/12 [00:03<00:00,  4.00it/s]
# 100%|██████████| 77/77 [00:16<00:00,  4.59it/s]
# 100%|██████████| 79/79 [00:18<00:00,  4.16it/s]
# 100%|██████████| 85/85 [00:19<00:00,  4.28it/s]
# 100%|██████████| 48/48 [00:10<00:00,  4.49it/s]
# 100%|██████████| 58/58 [00:13<00:00,  4.33it/s]
# 100%|██████████| 12/12 [00:02<00:00,  4.49it/s]
# 100%|██████████| 23/23 [00:05<00:00,  3.92it/s]
# 100%|██████████| 35/35 [00:07<00:00,  4.50it/s]
# 100%|██████████| 12/12 [00:03<00:00,  3.88it/s]
# 100%|██████████| 260/260 [00:59<00:00,  4.36it/s]
# 100%|██████████| 72/72 [00:16<00:00,  4.43it/s]
# 100%|██████████| 81/81 [00:19<00:00,  4.18it/s]
# 100%|██████████| 45/45 [00:09<00:00,  4.55it/s]
# 100%|██████████| 60/60 [00:14<00:00,  4.21it/s]
# 100%|██████████| 12/12 [00:02<00:00,  5.03it/s]
# 100%|██████████| 24/24 [00:05<00:00,  4.53it/s]
# 100%|██████████| 36/36 [00:07<00:00,  4.50it/s]
# 100%|██████████| 12/12 [00:02<00:00,  4.40it/s]
# 100%|██████████| 2/2 [00:00<00:00,  5.19it/s]
# 100%|██████████| 270/270 [01:04<00:00,  4.21it/s]
# 100%|██████████| 73/73 [00:17<00:00,  4.20it/s]
# 100%|██████████| 81/81 [00:17<00:00,  4.64it/s]
# 100%|██████████| 48/48 [00:11<00:00,  4.24it/s]
# 100%|██████████| 59/59 [00:13<00:00,  4.39it/s]
# 100%|██████████| 12/12 [00:02<00:00,  4.25it/s]
# 100%|██████████| 24/24 [00:05<00:00,  4.55it/s]
# 100%|██████████| 36/36 [00:07<00:00,  4.91it/s]
# 100%|██████████| 10/10 [00:02<00:00,  4.32it/s]
# 100%|██████████| 280/280 [01:03<00:00,  4.38it/s]
# 100%|██████████| 76/76 [00:18<00:00,  4.12it/s]
# 100%|██████████| 84/84 [00:19<00:00,  4.38it/s]
# 100%|██████████| 47/47 [00:11<00:00,  4.26it/s]
# 100%|██████████| 61/61 [00:13<00:00,  4.60it/s]
# 100%|██████████| 12/12 [00:02<00:00,  4.31it/s]
# 100%|██████████| 24/24 [00:05<00:00,  4.41it/s]
# 100%|██████████| 36/36 [00:08<00:00,  4.37it/s]
# 100%|██████████| 12/12 [00:02<00:00,  4.44it/s]
# 100%|██████████| 280/280 [01:01<00:00,  4.55it/s]
# 100%|██████████| 71/71 [00:16<00:00,  4.23it/s]
# 100%|██████████| 87/87 [00:18<00:00,  4.67it/s]
# 100%|██████████| 47/47 [00:11<00:00,  4.20it/s]
# 100%|██████████| 58/58 [00:13<00:00,  4.40it/s]
# 100%|██████████| 12/12 [00:02<00:00,  4.25it/s]
# 100%|██████████| 24/24 [00:06<00:00,  3.78it/s]
# 100%|██████████| 36/36 [00:09<00:00,  3.88it/s]
# 100%|██████████| 12/12 [00:03<00:00,  3.62it/s]
# 100%|██████████| 290/290 [01:06<00:00,  4.39it/s]
# 100%|██████████| 74/74 [00:16<00:00,  4.38it/s]
# 100%|██████████| 85/85 [00:21<00:00,  4.03it/s]
# 100%|██████████| 46/46 [00:10<00:00,  4.44it/s]
# 100%|██████████| 60/60 [00:13<00:00,  4.54it/s]
# 100%|██████████| 12/12 [00:02<00:00,  5.13it/s]
# 100%|██████████| 23/23 [00:05<00:00,  4.27it/s]
# 100%|██████████| 36/36 [00:08<00:00,  4.31it/s]
# 100%|██████████| 12/12 [00:03<00:00,  3.56it/s]
# 100%|██████████| 293/293 [01:07<00:00,  4.31it/s]
# 100%|██████████| 72/72 [00:17<00:00,  4.15it/s]
# 100%|██████████| 84/84 [00:20<00:00,  4.16it/s]
# 100%|██████████| 48/48 [00:11<00:00,  4.23it/s]
# 100%|██████████| 61/61 [00:15<00:00,  3.97it/s]
# 100%|██████████| 12/12 [00:02<00:00,  4.39it/s]
# 100%|██████████| 23/23 [00:05<00:00,  4.31it/s]
# 100%|██████████| 36/36 [00:08<00:00,  4.34it/s]
# 100%|██████████| 12/12 [00:02<00:00,  4.06it/s]
# 100%|██████████| 292/292 [01:07<00:00,  4.33it/s]
# 100%|██████████| 70/70 [00:15<00:00,  4.40it/s]
# 100%|██████████| 79/79 [00:18<00:00,  4.38it/s]
# 100%|██████████| 36/36 [00:08<00:00,  4.30it/s]
# 100%|██████████| 59/59 [00:13<00:00,  4.40it/s]
# 100%|██████████| 12/12 [00:02<00:00,  4.53it/s]
# 100%|██████████| 23/23 [00:04<00:00,  4.82it/s]
# 100%|██████████| 34/34 [00:07<00:00,  4.47it/s]
# 100%|██████████| 12/12 [00:02<00:00,  4.79it/s]
# 100%|██████████| 48/48 [00:11<00:00,  4.15it/s]
# 100%|██████████| 12/12 [00:02<00:00,  4.17it/s]
# 100%|██████████| 24/24 [00:05<00:00,  4.15it/s]
# 100%|██████████| 12/12 [00:03<00:00,  3.78it/s]
# 100%|██████████| 12/12 [00:02<00:00,  4.94it/s]
# 100%|██████████| 12/12 [00:02<00:00,  4.64it/s]
# 100%|██████████| 12/12 [00:02<00:00,  4.32it/s]
# 100%|██████████| 12/12 [00:02<00:00,  4.78it/s]
# 100%|██████████| 12/12 [00:02<00:00,  4.56it/s]
# 100%|██████████| 12/12 [00:02<00:00,  4.94it/s]
# 100%|██████████| 290/290 [01:05<00:00,  4.43it/s]
# 100%|██████████| 72/72 [00:17<00:00,  4.16it/s]
# 100%|██████████| 82/82 [00:18<00:00,  4.45it/s]
# 100%|██████████| 50/50 [00:10<00:00,  4.82it/s]
# 100%|██████████| 61/61 [00:12<00:00,  4.85it/s]
# 100%|██████████| 13/13 [00:02<00:00,  4.43it/s]
# 100%|██████████| 23/23 [00:05<00:00,  4.53it/s]
# 100%|██████████| 34/34 [00:07<00:00,  4.38it/s]
# 100%|██████████| 12/12 [00:03<00:00,  3.59it/s]
# 100%|██████████| 294/294 [01:07<00:00,  4.34it/s]
# 100%|██████████| 72/72 [00:16<00:00,  4.37it/s]
# 100%|██████████| 87/87 [00:21<00:00,  4.08it/s]
# 100%|██████████| 48/48 [00:11<00:00,  4.08it/s]
# 100%|██████████| 57/57 [00:13<00:00,  4.29it/s]
# 100%|██████████| 12/12 [00:02<00:00,  4.09it/s]
# 100%|██████████| 24/24 [00:06<00:00,  3.97it/s]
# 100%|██████████| 36/36 [00:08<00:00,  4.40it/s]
# 100%|██████████| 11/11 [00:02<00:00,  4.56it/s]
# 100%|██████████| 12/12 [00:02<00:00,  4.43it/s]
# 100%|██████████| 292/292 [01:05<00:00,  4.45it/s]
# 100%|██████████| 82/82 [00:18<00:00,  4.44it/s]
# 100%|██████████| 92/92 [00:20<00:00,  4.51it/s]
# 100%|██████████| 50/50 [00:11<00:00,  4.52it/s]
# 100%|██████████| 63/63 [00:13<00:00,  4.59it/s]
# 100%|██████████| 13/13 [00:03<00:00,  4.22it/s]
# 100%|██████████| 27/27 [00:06<00:00,  4.46it/s]
# 100%|██████████| 36/36 [00:07<00:00,  4.97it/s]
# 100%|██████████| 11/11 [00:02<00:00,  4.29it/s]
# 100%|██████████| 292/292 [01:05<00:00,  4.46it/s]
# 100%|██████████| 73/73 [00:16<00:00,  4.35it/s]
# 100%|██████████| 80/80 [00:17<00:00,  4.55it/s]
# 100%|██████████| 48/48 [00:10<00:00,  4.39it/s]
# 100%|██████████| 61/61 [00:12<00:00,  4.92it/s]
# 100%|██████████| 12/12 [00:02<00:00,  4.47it/s]
# 100%|██████████| 26/26 [00:06<00:00,  4.16it/s]
# 100%|██████████| 36/36 [00:07<00:00,  4.71it/s]
# 100%|██████████| 12/12 [00:02<00:00,  4.36it/s]
# 100%|██████████| 77/77 [00:16<00:00,  4.72it/s]
# 100%|██████████| 67/67 [00:14<00:00,  4.61it/s]
# 100%|██████████| 68/68 [00:15<00:00,  4.28it/s]
# 100%|██████████| 54/54 [00:12<00:00,  4.45it/s]
# 100%|██████████| 58/58 [00:12<00:00,  4.77it/s]
# 100%|██████████| 16/16 [00:03<00:00,  4.74it/s]
# 100%|██████████| 25/25 [00:05<00:00,  4.79it/s]
# 100%|██████████| 36/36 [00:08<00:00,  4.35it/s]
# 100%|██████████| 3/3 [00:00<00:00,  5.43it/s]
# 100%|██████████| 85/85 [00:19<00:00,  4.28it/s]
# 100%|██████████| 72/72 [00:16<00:00,  4.26it/s]
# 100%|██████████| 93/93 [00:20<00:00,  4.52it/s]
# 100%|██████████| 47/47 [00:09<00:00,  4.91it/s]
# 100%|██████████| 58/58 [00:12<00:00,  4.68it/s]
# 100%|██████████| 10/10 [00:02<00:00,  4.25it/s]
# 100%|██████████| 24/24 [00:05<00:00,  4.38it/s]
# 100%|██████████| 36/36 [00:07<00:00,  4.77it/s]
# 100%|██████████| 13/13 [00:02<00:00,  4.37it/s]
# 100%|██████████| 77/77 [00:16<00:00,  4.75it/s]
# 100%|██████████| 73/73 [00:14<00:00,  5.02it/s]
# 100%|██████████| 85/85 [00:18<00:00,  4.59it/s]
# 100%|██████████| 44/44 [00:09<00:00,  4.70it/s]
# 100%|██████████| 60/60 [00:13<00:00,  4.31it/s]
# 100%|██████████| 12/12 [00:02<00:00,  4.21it/s]
# 100%|██████████| 23/23 [00:05<00:00,  4.06it/s]
# 100%|██████████| 36/36 [00:07<00:00,  4.77it/s]
# 100%|██████████| 12/12 [00:02<00:00,  4.84it/s]
# 100%|██████████| 77/77 [00:16<00:00,  4.69it/s]
# 100%|██████████| 73/73 [00:15<00:00,  4.62it/s]
# 100%|██████████| 80/80 [00:17<00:00,  4.63it/s]
# 100%|██████████| 45/45 [00:09<00:00,  4.59it/s]
# 100%|██████████| 58/58 [00:12<00:00,  4.83it/s]
# 100%|██████████| 11/11 [00:02<00:00,  5.22it/s]
# 100%|██████████| 24/24 [00:05<00:00,  4.32it/s]
# 100%|██████████| 35/35 [00:06<00:00,  5.00it/s]
# 100%|██████████| 12/12 [00:02<00:00,  4.73it/s]
# 100%|██████████| 79/79 [00:17<00:00,  4.61it/s]
# 100%|██████████| 74/74 [00:15<00:00,  4.63it/s]
# 100%|██████████| 84/84 [00:17<00:00,  4.78it/s]
# 100%|██████████| 55/55 [00:11<00:00,  4.69it/s]
# 100%|██████████| 58/58 [00:11<00:00,  5.08it/s]
# 100%|██████████| 11/11 [00:02<00:00,  4.63it/s]
# 100%|██████████| 20/20 [00:03<00:00,  5.13it/s]
# 100%|██████████| 34/34 [00:07<00:00,  4.29it/s]
# 100%|██████████| 11/11 [00:02<00:00,  5.02it/s]
# 100%|██████████| 75/75 [00:15<00:00,  4.72it/s]
# 100%|██████████| 81/81 [00:17<00:00,  4.53it/s]
# 100%|██████████| 94/94 [00:20<00:00,  4.52it/s]
# 100%|██████████| 36/36 [00:07<00:00,  4.77it/s]
# 100%|██████████| 50/50 [00:10<00:00,  4.65it/s]
# 100%|██████████| 8/8 [00:01<00:00,  4.66it/s]
# 100%|██████████| 18/18 [00:03<00:00,  4.76it/s]
# 100%|██████████| 33/33 [00:07<00:00,  4.56it/s]
# 100%|██████████| 22/22 [00:05<00:00,  4.30it/s]
# 100%|██████████| 77/77 [00:16<00:00,  4.62it/s]
# 100%|██████████| 71/71 [00:14<00:00,  4.96it/s]
# 100%|██████████| 82/82 [00:18<00:00,  4.49it/s]
# 100%|██████████| 46/46 [00:10<00:00,  4.52it/s]
# 100%|██████████| 58/58 [00:13<00:00,  4.46it/s]
# 100%|██████████| 11/11 [00:02<00:00,  4.58it/s]
# 100%|██████████| 24/24 [00:05<00:00,  4.20it/s]
# 100%|██████████| 36/36 [00:07<00:00,  4.67it/s]
# 100%|██████████| 11/11 [00:02<00:00,  4.98it/s]
# 100%|██████████| 75/75 [00:15<00:00,  4.70it/s]
# 100%|██████████| 73/73 [00:15<00:00,  4.79it/s]
# 100%|██████████| 95/95 [00:20<00:00,  4.61it/s]
# 100%|██████████| 57/57 [00:11<00:00,  4.96it/s]
# 100%|██████████| 57/57 [00:11<00:00,  4.79it/s]
# 100%|██████████| 12/12 [00:02<00:00,  4.40it/s]
# 100%|██████████| 24/24 [00:05<00:00,  4.45it/s]
# 100%|██████████| 35/35 [00:07<00:00,  4.69it/s]
# 100%|██████████| 11/11 [00:02<00:00,  4.92it/s]
# 100%|██████████| 75/75 [00:15<00:00,  4.78it/s]
# 100%|██████████| 73/73 [00:15<00:00,  4.75it/s]
# 100%|██████████| 80/80 [00:17<00:00,  4.60it/s]
# 100%|██████████| 47/47 [00:09<00:00,  4.89it/s]
# 100%|██████████| 60/60 [00:13<00:00,  4.48it/s]
# 100%|██████████| 12/12 [00:02<00:00,  4.49it/s]
# 100%|██████████| 24/24 [00:05<00:00,  4.56it/s]
# 100%|██████████| 35/35 [00:08<00:00,  4.13it/s]
# 100%|██████████| 12/12 [00:02<00:00,  4.50it/s]
# 100%|██████████| 74/74 [00:17<00:00,  4.31it/s]
# 100%|██████████| 80/80 [00:16<00:00,  4.84it/s]
# 100%|██████████| 85/85 [00:18<00:00,  4.65it/s]
# 100%|██████████| 48/48 [00:10<00:00,  4.53it/s]
# 100%|██████████| 59/59 [00:12<00:00,  4.68it/s]
# 100%|██████████| 12/12 [00:02<00:00,  4.47it/s]
# 100%|██████████| 23/23 [00:04<00:00,  4.72it/s]
# 100%|██████████| 36/36 [00:07<00:00,  4.91it/s]
# 100%|██████████| 11/11 [00:02<00:00,  4.50it/s]
# 100%|██████████| 76/76 [00:16<00:00,  4.62it/s]
# 100%|██████████| 76/76 [00:16<00:00,  4.56it/s]
# 100%|██████████| 83/83 [00:18<00:00,  4.38it/s]
# 100%|██████████| 48/48 [00:10<00:00,  4.53it/s]
# 100%|██████████| 59/59 [00:13<00:00,  4.42it/s]
# 100%|██████████| 12/12 [00:02<00:00,  4.75it/s]
# 100%|██████████| 28/28 [00:06<00:00,  4.64it/s]
# 100%|██████████| 35/35 [00:07<00:00,  4.55it/s]
# 100%|██████████| 11/11 [00:02<00:00,  4.65it/s]
# 100%|██████████| 11/11 [00:02<00:00,  5.04it/s]
# 100%|██████████| 1/1 [00:00<00:00,  3.13it/s]
# 100%|██████████| 84/84 [00:17<00:00,  4.87it/s]
# 100%|██████████| 73/73 [00:16<00:00,  4.46it/s]
# 100%|██████████| 80/80 [00:17<00:00,  4.46it/s]
# 100%|██████████| 47/47 [00:09<00:00,  4.82it/s]
# 100%|██████████| 49/49 [00:10<00:00,  4.61it/s]
# 100%|██████████| 12/12 [00:02<00:00,  5.44it/s]
# 100%|██████████| 25/25 [00:04<00:00,  5.51it/s]
# 100%|██████████| 37/37 [00:07<00:00,  5.15it/s]
# 100%|██████████| 12/12 [00:02<00:00,  5.07it/s]
# 100%|██████████| 77/77 [00:17<00:00,  4.49it/s]
# 100%|██████████| 72/72 [00:16<00:00,  4.44it/s]
# 100%|██████████| 85/85 [00:18<00:00,  4.65it/s]
# 100%|██████████| 47/47 [00:09<00:00,  4.96it/s]
# 100%|██████████| 62/62 [00:13<00:00,  4.45it/s]
# 100%|██████████| 12/12 [00:02<00:00,  4.69it/s]
# 100%|██████████| 24/24 [00:05<00:00,  4.59it/s]
# 100%|██████████| 35/35 [00:07<00:00,  4.61it/s]
# 100%|██████████| 12/12 [00:03<00:00,  3.92it/s]
# 100%|██████████| 74/74 [00:15<00:00,  4.66it/s]
# 100%|██████████| 70/70 [00:15<00:00,  4.44it/s]
# 100%|██████████| 61/61 [00:13<00:00,  4.51it/s]
# 100%|██████████| 48/48 [00:10<00:00,  4.76it/s]
# 100%|██████████| 57/57 [00:12<00:00,  4.75it/s]
# 100%|██████████| 9/9 [00:02<00:00,  4.37it/s]
# 100%|██████████| 16/16 [00:03<00:00,  4.59it/s]
# 100%|██████████| 34/34 [00:07<00:00,  4.78it/s]
# 100%|██████████| 10/10 [00:01<00:00,  5.05it/s]
# (28, 28)
# 27
# 167
# 149
# 159
# 65
# 195
# 268
# 107
# 94
# 132
# 167
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 3, 3, 128)         73856
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 128)               0
#
#  dense (Dense)               (None, 100)               12900
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense_1 (Dense)             (None, 351)               35451
#
# =================================================================
# Total params: 141,023
# Trainable params: 141,023
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 252/252 - 16s - loss: 5.3934 - accuracy: 0.0239 - val_loss: 4.7585 - val_accuracy: 0.0659 - 16s/epoch - 64ms/step
# Epoch 2/200
# 252/252 - 15s - loss: 4.4398 - accuracy: 0.0942 - val_loss: 3.8529 - val_accuracy: 0.1764 - 15s/epoch - 60ms/step
# Epoch 3/200
# 252/252 - 15s - loss: 3.6848 - accuracy: 0.1902 - val_loss: 3.2036 - val_accuracy: 0.2821 - 15s/epoch - 61ms/step
# Epoch 4/200
# 252/252 - 15s - loss: 3.1828 - accuracy: 0.2652 - val_loss: 2.7779 - val_accuracy: 0.3492 - 15s/epoch - 59ms/step
# Epoch 5/200
# 252/252 - 15s - loss: 2.8198 - accuracy: 0.3214 - val_loss: 2.5487 - val_accuracy: 0.3892 - 15s/epoch - 60ms/step
# Epoch 6/200
# 252/252 - 15s - loss: 2.5693 - accuracy: 0.3566 - val_loss: 2.4384 - val_accuracy: 0.4120 - 15s/epoch - 60ms/step
# Epoch 7/200
# 252/252 - 15s - loss: 2.3744 - accuracy: 0.3951 - val_loss: 2.2108 - val_accuracy: 0.4371 - 15s/epoch - 59ms/step
# Epoch 8/200
# 252/252 - 15s - loss: 2.2117 - accuracy: 0.4244 - val_loss: 2.1034 - val_accuracy: 0.4692 - 15s/epoch - 59ms/step
# Epoch 9/200
# 252/252 - 15s - loss: 2.0554 - accuracy: 0.4571 - val_loss: 2.0294 - val_accuracy: 0.4761 - 15s/epoch - 60ms/step
# Epoch 10/200
# 252/252 - 15s - loss: 1.9617 - accuracy: 0.4770 - val_loss: 2.0014 - val_accuracy: 0.4836 - 15s/epoch - 60ms/step
# Epoch 11/200
# 252/252 - 15s - loss: 1.8569 - accuracy: 0.5005 - val_loss: 1.8797 - val_accuracy: 0.5060 - 15s/epoch - 59ms/step
# Epoch 12/200
# 252/252 - 15s - loss: 1.7420 - accuracy: 0.5232 - val_loss: 1.8531 - val_accuracy: 0.5176 - 15s/epoch - 60ms/step
# Epoch 13/200
# 252/252 - 15s - loss: 1.6743 - accuracy: 0.5336 - val_loss: 1.8168 - val_accuracy: 0.5271 - 15s/epoch - 59ms/step
# Epoch 14/200
# 252/252 - 15s - loss: 1.6053 - accuracy: 0.5500 - val_loss: 1.7730 - val_accuracy: 0.5321 - 15s/epoch - 59ms/step
# Epoch 15/200
# 252/252 - 15s - loss: 1.5414 - accuracy: 0.5654 - val_loss: 1.7300 - val_accuracy: 0.5430 - 15s/epoch - 59ms/step
# Epoch 16/200
# 252/252 - 15s - loss: 1.4765 - accuracy: 0.5845 - val_loss: 1.6933 - val_accuracy: 0.5512 - 15s/epoch - 59ms/step
# Epoch 17/200
# 252/252 - 15s - loss: 1.4356 - accuracy: 0.5927 - val_loss: 1.6991 - val_accuracy: 0.5522 - 15s/epoch - 60ms/step
# Epoch 18/200
# 252/252 - 15s - loss: 1.3772 - accuracy: 0.6009 - val_loss: 1.6613 - val_accuracy: 0.5577 - 15s/epoch - 59ms/step
# Epoch 19/200
# 252/252 - 15s - loss: 1.3147 - accuracy: 0.6182 - val_loss: 1.6638 - val_accuracy: 0.5601 - 15s/epoch - 60ms/step
# Epoch 20/200
# 252/252 - 15s - loss: 1.2846 - accuracy: 0.6252 - val_loss: 1.6756 - val_accuracy: 0.5671 - 15s/epoch - 60ms/step
# Epoch 21/200
# 252/252 - 15s - loss: 1.2356 - accuracy: 0.6382 - val_loss: 1.6738 - val_accuracy: 0.5589 - 15s/epoch - 60ms/step
# Epoch 22/200
# 252/252 - 15s - loss: 1.1929 - accuracy: 0.6505 - val_loss: 1.6399 - val_accuracy: 0.5736 - 15s/epoch - 60ms/step
# Epoch 23/200
# 252/252 - 15s - loss: 1.1536 - accuracy: 0.6562 - val_loss: 1.6150 - val_accuracy: 0.5775 - 15s/epoch - 60ms/step
# Epoch 24/200
# 252/252 - 15s - loss: 1.1298 - accuracy: 0.6674 - val_loss: 1.6131 - val_accuracy: 0.5934 - 15s/epoch - 59ms/step
# Epoch 25/200
# 252/252 - 15s - loss: 1.0915 - accuracy: 0.6707 - val_loss: 1.6443 - val_accuracy: 0.5753 - 15s/epoch - 59ms/step
# Epoch 26/200
# 252/252 - 15s - loss: 1.0645 - accuracy: 0.6825 - val_loss: 1.6242 - val_accuracy: 0.5828 - 15s/epoch - 59ms/step
# Epoch 27/200
# 252/252 - 15s - loss: 1.0386 - accuracy: 0.6849 - val_loss: 1.6153 - val_accuracy: 0.5890 - 15s/epoch - 59ms/step
# Epoch 28/200
# 252/252 - 15s - loss: 1.0201 - accuracy: 0.6946 - val_loss: 1.6327 - val_accuracy: 0.5929 - 15s/epoch - 60ms/step
# Epoch 29/200
# 252/252 - 15s - loss: 0.9736 - accuracy: 0.6976 - val_loss: 1.6314 - val_accuracy: 0.5800 - 15s/epoch - 59ms/step
# Epoch 30/200
# 252/252 - 15s - loss: 0.9480 - accuracy: 0.7098 - val_loss: 1.6299 - val_accuracy: 0.5865 - 15s/epoch - 59ms/step
# Epoch 31/200
# 252/252 - 15s - loss: 0.9284 - accuracy: 0.7131 - val_loss: 1.6325 - val_accuracy: 0.5992 - 15s/epoch - 59ms/step
# Epoch 32/200
# 252/252 - 15s - loss: 0.9027 - accuracy: 0.7192 - val_loss: 1.6548 - val_accuracy: 0.5882 - 15s/epoch - 59ms/step
# Epoch 33/200
# 252/252 - 15s - loss: 0.8717 - accuracy: 0.7319 - val_loss: 1.6803 - val_accuracy: 0.5857 - 15s/epoch - 59ms/step
# Epoch 34/200
# 252/252 - 15s - loss: 0.8744 - accuracy: 0.7260 - val_loss: 1.6545 - val_accuracy: 0.5982 - 15s/epoch - 59ms/step
# Epoch 35/200
# 252/252 - 15s - loss: 0.8265 - accuracy: 0.7371 - val_loss: 1.6756 - val_accuracy: 0.5962 - 15s/epoch - 59ms/step
# Epoch 36/200
# 252/252 - 15s - loss: 0.7969 - accuracy: 0.7505 - val_loss: 1.7050 - val_accuracy: 0.5942 - 15s/epoch - 59ms/step
# Epoch 37/200
# 252/252 - 15s - loss: 0.8138 - accuracy: 0.7441 - val_loss: 1.7475 - val_accuracy: 0.5962 - 15s/epoch - 59ms/step
# Epoch 38/200
# 252/252 - 15s - loss: 0.7692 - accuracy: 0.7537 - val_loss: 1.7478 - val_accuracy: 0.5967 - 15s/epoch - 59ms/step
# Epoch 39/200
# 252/252 - 15s - loss: 0.7560 - accuracy: 0.7640 - val_loss: 1.7141 - val_accuracy: 0.5947 - 15s/epoch - 59ms/step
# Epoch 40/200
# 252/252 - 15s - loss: 0.7397 - accuracy: 0.7649 - val_loss: 1.7574 - val_accuracy: 0.5890 - 15s/epoch - 60ms/step
# Epoch 41/200
# 252/252 - 15s - loss: 0.7271 - accuracy: 0.7667 - val_loss: 1.7624 - val_accuracy: 0.5979 - 15s/epoch - 60ms/step
# Epoch 42/200
# 252/252 - 15s - loss: 0.6987 - accuracy: 0.7792 - val_loss: 1.7633 - val_accuracy: 0.6009 - 15s/epoch - 59ms/step
# Epoch 43/200
# 252/252 - 15s - loss: 0.6964 - accuracy: 0.7791 - val_loss: 1.7939 - val_accuracy: 0.5910 - 15s/epoch - 60ms/step
# Epoch 44/200
# 252/252 - 15s - loss: 0.6902 - accuracy: 0.7793 - val_loss: 1.8723 - val_accuracy: 0.5847 - 15s/epoch - 60ms/step
# Epoch 45/200
# 252/252 - 15s - loss: 0.6802 - accuracy: 0.7803 - val_loss: 1.8281 - val_accuracy: 0.5852 - 15s/epoch - 60ms/step
# Epoch 46/200
# 252/252 - 15s - loss: 0.6579 - accuracy: 0.7891 - val_loss: 1.8771 - val_accuracy: 0.5882 - 15s/epoch - 60ms/step
# Epoch 47/200
# 252/252 - 15s - loss: 0.6419 - accuracy: 0.7943 - val_loss: 1.9195 - val_accuracy: 0.5947 - 15s/epoch - 59ms/step
# Epoch 48/200
# 252/252 - 15s - loss: 0.6209 - accuracy: 0.7990 - val_loss: 1.8759 - val_accuracy: 0.5972 - 15s/epoch - 60ms/step
# Epoch 49/200
# 252/252 - 15s - loss: 0.6173 - accuracy: 0.7982 - val_loss: 1.9810 - val_accuracy: 0.5954 - 15s/epoch - 60ms/step
# Epoch 50/200
# 252/252 - 15s - loss: 0.6017 - accuracy: 0.8025 - val_loss: 1.9304 - val_accuracy: 0.5939 - 15s/epoch - 59ms/step
# Epoch 51/200
# 252/252 - 15s - loss: 0.5973 - accuracy: 0.8047 - val_loss: 2.0560 - val_accuracy: 0.5919 - 15s/epoch - 59ms/step
# Epoch 52/200
# 252/252 - 15s - loss: 0.5808 - accuracy: 0.8122 - val_loss: 1.9864 - val_accuracy: 0.5929 - 15s/epoch - 59ms/step
# Epoch 53/200
# 252/252 - 15s - loss: 0.5625 - accuracy: 0.8203 - val_loss: 1.9689 - val_accuracy: 0.5857 - 15s/epoch - 59ms/step
# Epoch 54/200
# 252/252 - 15s - loss: 0.5623 - accuracy: 0.8177 - val_loss: 2.0248 - val_accuracy: 0.5929 - 15s/epoch - 59ms/step
# Epoch 55/200
# 252/252 - 15s - loss: 0.5569 - accuracy: 0.8157 - val_loss: 2.0260 - val_accuracy: 0.5855 - 15s/epoch - 59ms/step
# Epoch 56/200
# 252/252 - 15s - loss: 0.5353 - accuracy: 0.8278 - val_loss: 2.0615 - val_accuracy: 0.5828 - 15s/epoch - 59ms/step
# Epoch 57/200
# 252/252 - 15s - loss: 0.5333 - accuracy: 0.8241 - val_loss: 2.0881 - val_accuracy: 0.5907 - 15s/epoch - 60ms/step
# Epoch 58/200
# 252/252 - 15s - loss: 0.5142 - accuracy: 0.8315 - val_loss: 2.0599 - val_accuracy: 0.5942 - 15s/epoch - 58ms/step
# Epoch 59/200
# 252/252 - 15s - loss: 0.5061 - accuracy: 0.8337 - val_loss: 2.0919 - val_accuracy: 0.5977 - 15s/epoch - 59ms/step
# Epoch 60/200
# 252/252 - 15s - loss: 0.5045 - accuracy: 0.8352 - val_loss: 2.1626 - val_accuracy: 0.5902 - 15s/epoch - 58ms/step
# Epoch 61/200
# 252/252 - 15s - loss: 0.5031 - accuracy: 0.8342 - val_loss: 2.1168 - val_accuracy: 0.5892 - 15s/epoch - 58ms/step
# Epoch 62/200
# 252/252 - 15s - loss: 0.4902 - accuracy: 0.8359 - val_loss: 2.1362 - val_accuracy: 0.5875 - 15s/epoch - 58ms/step
# Epoch 63/200
# 252/252 - 15s - loss: 0.4760 - accuracy: 0.8415 - val_loss: 2.1574 - val_accuracy: 0.5964 - 15s/epoch - 58ms/step
# Epoch 64/200
# 252/252 - 15s - loss: 0.4713 - accuracy: 0.8464 - val_loss: 2.1559 - val_accuracy: 0.5939 - 15s/epoch - 59ms/step
# Epoch 65/200
# 252/252 - 15s - loss: 0.4506 - accuracy: 0.8549 - val_loss: 2.2000 - val_accuracy: 0.5947 - 15s/epoch - 58ms/step
# Epoch 66/200
# 252/252 - 15s - loss: 0.4583 - accuracy: 0.8493 - val_loss: 2.2322 - val_accuracy: 0.5902 - 15s/epoch - 58ms/step
# Epoch 67/200
# 252/252 - 15s - loss: 0.4529 - accuracy: 0.8511 - val_loss: 2.2432 - val_accuracy: 0.5907 - 15s/epoch - 58ms/step
# Epoch 68/200
# 252/252 - 15s - loss: 0.4377 - accuracy: 0.8566 - val_loss: 2.2354 - val_accuracy: 0.5887 - 15s/epoch - 59ms/step
# Epoch 69/200
# 252/252 - 15s - loss: 0.4307 - accuracy: 0.8600 - val_loss: 2.3048 - val_accuracy: 0.5825 - 15s/epoch - 59ms/step
# Epoch 70/200
# 252/252 - 15s - loss: 0.4367 - accuracy: 0.8581 - val_loss: 2.2925 - val_accuracy: 0.5912 - 15s/epoch - 59ms/step
# Epoch 71/200
# 252/252 - 15s - loss: 0.4218 - accuracy: 0.8621 - val_loss: 2.2964 - val_accuracy: 0.5900 - 15s/epoch - 59ms/step
# Epoch 72/200
# 252/252 - 15s - loss: 0.4216 - accuracy: 0.8623 - val_loss: 2.3427 - val_accuracy: 0.5830 - 15s/epoch - 59ms/step
# Epoch 73/200
# 252/252 - 15s - loss: 0.4022 - accuracy: 0.8667 - val_loss: 2.3599 - val_accuracy: 0.5887 - 15s/epoch - 59ms/step
# Epoch 74/200
# 252/252 - 15s - loss: 0.4161 - accuracy: 0.8631 - val_loss: 2.3981 - val_accuracy: 0.5875 - 15s/epoch - 59ms/step
# Epoch 75/200
# 252/252 - 15s - loss: 0.3959 - accuracy: 0.8687 - val_loss: 2.3788 - val_accuracy: 0.5867 - 15s/epoch - 59ms/step
# Epoch 76/200
# 252/252 - 15s - loss: 0.3885 - accuracy: 0.8711 - val_loss: 2.4478 - val_accuracy: 0.5855 - 15s/epoch - 59ms/step
# Epoch 77/200
# 252/252 - 15s - loss: 0.3898 - accuracy: 0.8724 - val_loss: 2.4560 - val_accuracy: 0.5895 - 15s/epoch - 59ms/step
# Epoch 78/200
# 252/252 - 15s - loss: 0.3848 - accuracy: 0.8724 - val_loss: 2.5002 - val_accuracy: 0.5815 - 15s/epoch - 59ms/step
# Epoch 79/200
# 252/252 - 15s - loss: 0.3785 - accuracy: 0.8776 - val_loss: 2.5510 - val_accuracy: 0.5892 - 15s/epoch - 59ms/step
# Epoch 80/200
# 252/252 - 15s - loss: 0.3737 - accuracy: 0.8764 - val_loss: 2.5454 - val_accuracy: 0.5731 - 15s/epoch - 59ms/step
# Epoch 81/200
# 252/252 - 15s - loss: 0.3745 - accuracy: 0.8781 - val_loss: 2.5560 - val_accuracy: 0.5840 - 15s/epoch - 59ms/step
# Epoch 82/200
# 252/252 - 15s - loss: 0.3677 - accuracy: 0.8821 - val_loss: 2.6434 - val_accuracy: 0.5825 - 15s/epoch - 59ms/step
# Epoch 83/200
# 252/252 - 15s - loss: 0.3531 - accuracy: 0.8837 - val_loss: 2.5690 - val_accuracy: 0.5825 - 15s/epoch - 59ms/step
# Epoch 84/200
# 252/252 - 15s - loss: 0.3680 - accuracy: 0.8787 - val_loss: 2.5287 - val_accuracy: 0.5897 - 15s/epoch - 59ms/step
# Epoch 85/200
# 252/252 - 15s - loss: 0.3428 - accuracy: 0.8868 - val_loss: 2.7180 - val_accuracy: 0.5800 - 15s/epoch - 58ms/step
# Epoch 86/200
# 252/252 - 15s - loss: 0.3669 - accuracy: 0.8788 - val_loss: 2.6128 - val_accuracy: 0.5828 - 15s/epoch - 59ms/step
# Epoch 87/200
# 252/252 - 15s - loss: 0.3550 - accuracy: 0.8842 - val_loss: 2.6588 - val_accuracy: 0.5805 - 15s/epoch - 59ms/step
# Epoch 88/200
# 252/252 - 15s - loss: 0.3429 - accuracy: 0.8846 - val_loss: 2.6992 - val_accuracy: 0.5793 - 15s/epoch - 59ms/step
# Epoch 89/200
# 252/252 - 15s - loss: 0.3274 - accuracy: 0.8920 - val_loss: 2.7767 - val_accuracy: 0.5835 - 15s/epoch - 59ms/step
# Epoch 90/200
# 252/252 - 15s - loss: 0.3223 - accuracy: 0.8931 - val_loss: 2.7690 - val_accuracy: 0.5731 - 15s/epoch - 60ms/step
# Epoch 91/200
# 252/252 - 15s - loss: 0.3314 - accuracy: 0.8874 - val_loss: 2.7117 - val_accuracy: 0.5805 - 15s/epoch - 59ms/step
# Epoch 92/200
# 252/252 - 15s - loss: 0.3360 - accuracy: 0.8881 - val_loss: 2.7689 - val_accuracy: 0.5798 - 15s/epoch - 59ms/step
# Epoch 93/200
# 252/252 - 15s - loss: 0.3398 - accuracy: 0.8896 - val_loss: 2.7692 - val_accuracy: 0.5852 - 15s/epoch - 59ms/step
# Epoch 94/200
# 252/252 - 15s - loss: 0.3127 - accuracy: 0.8971 - val_loss: 2.7916 - val_accuracy: 0.5770 - 15s/epoch - 60ms/step
# Epoch 95/200
# 252/252 - 15s - loss: 0.3175 - accuracy: 0.8946 - val_loss: 2.8572 - val_accuracy: 0.5728 - 15s/epoch - 58ms/step
# Epoch 96/200
# 252/252 - 15s - loss: 0.3298 - accuracy: 0.8909 - val_loss: 2.8638 - val_accuracy: 0.5820 - 15s/epoch - 59ms/step
# Epoch 97/200
# 252/252 - 15s - loss: 0.2997 - accuracy: 0.9021 - val_loss: 2.7872 - val_accuracy: 0.5773 - 15s/epoch - 59ms/step
# Epoch 98/200
# 252/252 - 15s - loss: 0.3057 - accuracy: 0.8975 - val_loss: 2.8536 - val_accuracy: 0.5813 - 15s/epoch - 60ms/step
# Epoch 99/200
# 252/252 - 15s - loss: 0.2987 - accuracy: 0.9008 - val_loss: 2.9057 - val_accuracy: 0.5810 - 15s/epoch - 59ms/step
# Epoch 100/200
# 252/252 - 15s - loss: 0.3088 - accuracy: 0.8995 - val_loss: 2.8540 - val_accuracy: 0.5895 - 15s/epoch - 60ms/step
# Epoch 101/200
# 252/252 - 15s - loss: 0.3202 - accuracy: 0.8950 - val_loss: 2.9030 - val_accuracy: 0.5753 - 15s/epoch - 59ms/step
# Epoch 102/200
# 252/252 - 15s - loss: 0.3189 - accuracy: 0.8958 - val_loss: 2.9394 - val_accuracy: 0.5840 - 15s/epoch - 59ms/step
# Epoch 103/200
# 252/252 - 15s - loss: 0.2917 - accuracy: 0.9011 - val_loss: 2.9151 - val_accuracy: 0.5770 - 15s/epoch - 59ms/step
# Epoch 104/200
# 252/252 - 15s - loss: 0.3022 - accuracy: 0.9011 - val_loss: 3.0085 - val_accuracy: 0.5785 - 15s/epoch - 59ms/step
# Epoch 105/200
# 252/252 - 15s - loss: 0.2962 - accuracy: 0.9026 - val_loss: 2.9430 - val_accuracy: 0.5800 - 15s/epoch - 59ms/step
# Epoch 106/200
# 252/252 - 15s - loss: 0.2960 - accuracy: 0.9056 - val_loss: 2.9339 - val_accuracy: 0.5788 - 15s/epoch - 59ms/step
# Epoch 107/200
# 252/252 - 15s - loss: 0.2900 - accuracy: 0.9051 - val_loss: 3.0578 - val_accuracy: 0.5760 - 15s/epoch - 59ms/step
# Epoch 108/200
# 252/252 - 15s - loss: 0.3136 - accuracy: 0.8966 - val_loss: 2.9941 - val_accuracy: 0.5755 - 15s/epoch - 60ms/step
# Epoch 109/200
# 252/252 - 15s - loss: 0.2801 - accuracy: 0.9068 - val_loss: 2.9853 - val_accuracy: 0.5778 - 15s/epoch - 59ms/step
# Epoch 110/200
# 252/252 - 15s - loss: 0.2762 - accuracy: 0.9108 - val_loss: 3.0546 - val_accuracy: 0.5758 - 15s/epoch - 59ms/step
# Epoch 111/200
# 252/252 - 15s - loss: 0.2774 - accuracy: 0.9093 - val_loss: 3.1567 - val_accuracy: 0.5683 - 15s/epoch - 59ms/step
# Epoch 112/200
# 252/252 - 15s - loss: 0.2862 - accuracy: 0.9058 - val_loss: 3.0597 - val_accuracy: 0.5721 - 15s/epoch - 59ms/step
# Epoch 113/200
# 252/252 - 15s - loss: 0.2706 - accuracy: 0.9121 - val_loss: 3.0968 - val_accuracy: 0.5743 - 15s/epoch - 59ms/step
# Epoch 114/200
# 252/252 - 15s - loss: 0.2830 - accuracy: 0.9085 - val_loss: 3.1225 - val_accuracy: 0.5788 - 15s/epoch - 58ms/step
# Epoch 115/200
# 252/252 - 15s - loss: 0.2868 - accuracy: 0.9054 - val_loss: 3.1666 - val_accuracy: 0.5741 - 15s/epoch - 58ms/step
# Epoch 116/200
# 252/252 - 15s - loss: 0.2636 - accuracy: 0.9144 - val_loss: 3.0109 - val_accuracy: 0.5760 - 15s/epoch - 59ms/step
# Epoch 117/200
# 252/252 - 15s - loss: 0.2705 - accuracy: 0.9116 - val_loss: 3.1312 - val_accuracy: 0.5805 - 15s/epoch - 59ms/step
# Epoch 118/200
# 252/252 - 15s - loss: 0.2681 - accuracy: 0.9101 - val_loss: 3.0583 - val_accuracy: 0.5726 - 15s/epoch - 58ms/step
# Epoch 119/200
# 252/252 - 15s - loss: 0.2513 - accuracy: 0.9189 - val_loss: 3.2184 - val_accuracy: 0.5743 - 15s/epoch - 59ms/step
# Epoch 120/200
# 252/252 - 15s - loss: 0.2771 - accuracy: 0.9103 - val_loss: 3.0441 - val_accuracy: 0.5785 - 15s/epoch - 59ms/step
# Epoch 121/200
# 252/252 - 15s - loss: 0.2598 - accuracy: 0.9152 - val_loss: 3.2286 - val_accuracy: 0.5723 - 15s/epoch - 59ms/step
# Epoch 122/200
# 252/252 - 15s - loss: 0.2585 - accuracy: 0.9148 - val_loss: 3.2637 - val_accuracy: 0.5733 - 15s/epoch - 58ms/step
# Epoch 123/200
# 252/252 - 15s - loss: 0.2463 - accuracy: 0.9192 - val_loss: 3.1414 - val_accuracy: 0.5755 - 15s/epoch - 58ms/step
# Epoch 124/200
# 252/252 - 15s - loss: 0.2689 - accuracy: 0.9116 - val_loss: 3.1866 - val_accuracy: 0.5743 - 15s/epoch - 59ms/step
# Epoch 125/200
# 252/252 - 15s - loss: 0.2644 - accuracy: 0.9127 - val_loss: 3.2495 - val_accuracy: 0.5808 - 15s/epoch - 58ms/step
# Epoch 126/200
# 252/252 - 15s - loss: 0.2477 - accuracy: 0.9210 - val_loss: 3.2801 - val_accuracy: 0.5803 - 15s/epoch - 58ms/step
# Epoch 127/200
# 252/252 - 15s - loss: 0.2502 - accuracy: 0.9185 - val_loss: 3.1819 - val_accuracy: 0.5800 - 15s/epoch - 59ms/step
# Epoch 128/200
# 252/252 - 15s - loss: 0.2515 - accuracy: 0.9184 - val_loss: 3.1901 - val_accuracy: 0.5671 - 15s/epoch - 59ms/step
# Epoch 129/200
# 252/252 - 15s - loss: 0.2451 - accuracy: 0.9197 - val_loss: 3.3139 - val_accuracy: 0.5778 - 15s/epoch - 59ms/step
# Epoch 130/200
# 252/252 - 15s - loss: 0.2620 - accuracy: 0.9116 - val_loss: 3.4064 - val_accuracy: 0.5678 - 15s/epoch - 59ms/step
# Epoch 131/200
# 252/252 - 15s - loss: 0.2339 - accuracy: 0.9215 - val_loss: 3.3409 - val_accuracy: 0.5877 - 15s/epoch - 58ms/step
# Epoch 132/200
# 252/252 - 15s - loss: 0.2507 - accuracy: 0.9203 - val_loss: 3.2277 - val_accuracy: 0.5795 - 15s/epoch - 59ms/step
# Epoch 133/200
# 252/252 - 15s - loss: 0.2445 - accuracy: 0.9223 - val_loss: 3.3023 - val_accuracy: 0.5805 - 15s/epoch - 58ms/step
# Epoch 134/200
# 252/252 - 15s - loss: 0.2416 - accuracy: 0.9234 - val_loss: 3.3019 - val_accuracy: 0.5790 - 15s/epoch - 58ms/step
# Epoch 135/200
# 252/252 - 15s - loss: 0.2286 - accuracy: 0.9258 - val_loss: 3.3676 - val_accuracy: 0.5778 - 15s/epoch - 58ms/step
# Epoch 136/200
# 252/252 - 15s - loss: 0.2211 - accuracy: 0.9261 - val_loss: 3.3829 - val_accuracy: 0.5763 - 15s/epoch - 58ms/step
# Epoch 137/200
# 252/252 - 15s - loss: 0.2326 - accuracy: 0.9249 - val_loss: 3.4273 - val_accuracy: 0.5716 - 15s/epoch - 58ms/step
# Epoch 138/200
# 252/252 - 15s - loss: 0.2508 - accuracy: 0.9182 - val_loss: 3.3820 - val_accuracy: 0.5755 - 15s/epoch - 59ms/step
# Epoch 139/200
# 252/252 - 15s - loss: 0.2401 - accuracy: 0.9219 - val_loss: 3.4282 - val_accuracy: 0.5780 - 15s/epoch - 58ms/step
# Epoch 140/200
# 252/252 - 15s - loss: 0.2343 - accuracy: 0.9236 - val_loss: 3.4344 - val_accuracy: 0.5718 - 15s/epoch - 58ms/step
# Epoch 141/200
# 252/252 - 15s - loss: 0.2398 - accuracy: 0.9207 - val_loss: 3.4816 - val_accuracy: 0.5773 - 15s/epoch - 58ms/step
# Epoch 142/200
# 252/252 - 15s - loss: 0.2355 - accuracy: 0.9223 - val_loss: 3.4954 - val_accuracy: 0.5696 - 15s/epoch - 58ms/step
# Epoch 143/200
# 252/252 - 15s - loss: 0.2412 - accuracy: 0.9218 - val_loss: 3.3833 - val_accuracy: 0.5741 - 15s/epoch - 58ms/step
# Epoch 144/200
# 252/252 - 15s - loss: 0.2257 - accuracy: 0.9281 - val_loss: 3.4074 - val_accuracy: 0.5768 - 15s/epoch - 59ms/step
# Epoch 145/200
# 252/252 - 15s - loss: 0.2409 - accuracy: 0.9225 - val_loss: 3.4763 - val_accuracy: 0.5763 - 15s/epoch - 58ms/step
# Epoch 146/200
# 252/252 - 15s - loss: 0.2187 - accuracy: 0.9266 - val_loss: 3.5711 - val_accuracy: 0.5701 - 15s/epoch - 58ms/step
# Epoch 147/200
# 252/252 - 15s - loss: 0.2251 - accuracy: 0.9243 - val_loss: 3.5106 - val_accuracy: 0.5795 - 15s/epoch - 58ms/step
# Epoch 148/200
# 252/252 - 15s - loss: 0.2282 - accuracy: 0.9271 - val_loss: 3.4245 - val_accuracy: 0.5723 - 15s/epoch - 58ms/step
# Epoch 149/200
# 252/252 - 15s - loss: 0.2288 - accuracy: 0.9263 - val_loss: 3.6790 - val_accuracy: 0.5624 - 15s/epoch - 58ms/step
# Epoch 150/200
# 252/252 - 15s - loss: 0.2211 - accuracy: 0.9291 - val_loss: 3.6163 - val_accuracy: 0.5654 - 15s/epoch - 58ms/step
# Epoch 151/200
# 252/252 - 15s - loss: 0.2188 - accuracy: 0.9278 - val_loss: 3.6567 - val_accuracy: 0.5666 - 15s/epoch - 58ms/step
# Epoch 152/200
# 252/252 - 15s - loss: 0.2288 - accuracy: 0.9271 - val_loss: 3.4820 - val_accuracy: 0.5723 - 15s/epoch - 58ms/step
# Epoch 153/200
# 252/252 - 14s - loss: 0.2238 - accuracy: 0.9261 - val_loss: 3.5106 - val_accuracy: 0.5755 - 14s/epoch - 58ms/step
# Epoch 154/200
# 252/252 - 14s - loss: 0.2258 - accuracy: 0.9292 - val_loss: 3.5242 - val_accuracy: 0.5654 - 14s/epoch - 57ms/step
# Epoch 155/200
# 252/252 - 14s - loss: 0.2092 - accuracy: 0.9336 - val_loss: 3.5619 - val_accuracy: 0.5673 - 14s/epoch - 57ms/step
# Epoch 156/200
# 252/252 - 14s - loss: 0.2128 - accuracy: 0.9318 - val_loss: 3.6912 - val_accuracy: 0.5743 - 14s/epoch - 57ms/step
# Epoch 157/200
# 252/252 - 15s - loss: 0.2250 - accuracy: 0.9289 - val_loss: 3.6399 - val_accuracy: 0.5701 - 15s/epoch - 58ms/step
# Epoch 158/200
# 252/252 - 14s - loss: 0.2074 - accuracy: 0.9318 - val_loss: 3.6084 - val_accuracy: 0.5703 - 14s/epoch - 57ms/step
# Epoch 159/200
# 252/252 - 14s - loss: 0.2096 - accuracy: 0.9301 - val_loss: 3.6318 - val_accuracy: 0.5800 - 14s/epoch - 57ms/step
# Epoch 160/200
# 252/252 - 14s - loss: 0.2115 - accuracy: 0.9315 - val_loss: 3.7273 - val_accuracy: 0.5661 - 14s/epoch - 57ms/step
# Epoch 161/200
# 252/252 - 14s - loss: 0.2215 - accuracy: 0.9302 - val_loss: 3.7324 - val_accuracy: 0.5654 - 14s/epoch - 57ms/step
# Epoch 162/200
# 252/252 - 15s - loss: 0.2215 - accuracy: 0.9289 - val_loss: 3.7928 - val_accuracy: 0.5696 - 15s/epoch - 58ms/step
# Epoch 163/200
# 252/252 - 15s - loss: 0.2221 - accuracy: 0.9326 - val_loss: 3.6083 - val_accuracy: 0.5698 - 15s/epoch - 58ms/step
# Epoch 164/200
# 252/252 - 14s - loss: 0.2014 - accuracy: 0.9347 - val_loss: 3.6873 - val_accuracy: 0.5661 - 14s/epoch - 57ms/step
# Epoch 165/200
# 252/252 - 15s - loss: 0.2135 - accuracy: 0.9308 - val_loss: 3.6042 - val_accuracy: 0.5723 - 15s/epoch - 58ms/step
# Epoch 166/200
# 252/252 - 14s - loss: 0.2131 - accuracy: 0.9314 - val_loss: 3.7404 - val_accuracy: 0.5681 - 14s/epoch - 57ms/step
# Epoch 167/200
# 252/252 - 14s - loss: 0.1998 - accuracy: 0.9361 - val_loss: 3.6892 - val_accuracy: 0.5673 - 14s/epoch - 57ms/step
# Epoch 168/200
# 252/252 - 14s - loss: 0.2144 - accuracy: 0.9313 - val_loss: 3.7809 - val_accuracy: 0.5708 - 14s/epoch - 57ms/step
# Epoch 169/200
# 252/252 - 14s - loss: 0.1934 - accuracy: 0.9358 - val_loss: 3.7639 - val_accuracy: 0.5691 - 14s/epoch - 57ms/step
# Epoch 170/200
# 252/252 - 15s - loss: 0.1998 - accuracy: 0.9366 - val_loss: 3.7464 - val_accuracy: 0.5736 - 15s/epoch - 58ms/step
# Epoch 171/200
# 252/252 - 15s - loss: 0.1832 - accuracy: 0.9399 - val_loss: 3.6909 - val_accuracy: 0.5698 - 15s/epoch - 58ms/step
# Epoch 172/200
# 252/252 - 15s - loss: 0.1948 - accuracy: 0.9400 - val_loss: 3.7575 - val_accuracy: 0.5668 - 15s/epoch - 58ms/step
# Epoch 173/200
# 252/252 - 14s - loss: 0.2244 - accuracy: 0.9285 - val_loss: 3.9066 - val_accuracy: 0.5678 - 14s/epoch - 57ms/step
# Epoch 174/200
# 252/252 - 14s - loss: 0.2328 - accuracy: 0.9246 - val_loss: 3.7256 - val_accuracy: 0.5748 - 14s/epoch - 57ms/step
# Epoch 175/200
# 252/252 - 15s - loss: 0.1866 - accuracy: 0.9397 - val_loss: 3.8248 - val_accuracy: 0.5636 - 15s/epoch - 58ms/step
# Epoch 176/200
# 252/252 - 15s - loss: 0.1890 - accuracy: 0.9382 - val_loss: 3.7968 - val_accuracy: 0.5688 - 15s/epoch - 58ms/step
# Epoch 177/200
# 252/252 - 14s - loss: 0.2069 - accuracy: 0.9333 - val_loss: 3.7602 - val_accuracy: 0.5718 - 14s/epoch - 57ms/step
# Epoch 178/200
# 252/252 - 15s - loss: 0.2069 - accuracy: 0.9318 - val_loss: 3.9435 - val_accuracy: 0.5696 - 15s/epoch - 58ms/step
# Epoch 179/200
# 252/252 - 15s - loss: 0.1998 - accuracy: 0.9375 - val_loss: 3.8291 - val_accuracy: 0.5606 - 15s/epoch - 58ms/step
# Epoch 180/200
# 252/252 - 15s - loss: 0.1889 - accuracy: 0.9398 - val_loss: 3.8043 - val_accuracy: 0.5673 - 15s/epoch - 58ms/step
# Epoch 181/200
# 252/252 - 15s - loss: 0.1837 - accuracy: 0.9409 - val_loss: 3.9540 - val_accuracy: 0.5624 - 15s/epoch - 58ms/step
# Epoch 182/200
# 252/252 - 15s - loss: 0.1995 - accuracy: 0.9345 - val_loss: 3.7901 - val_accuracy: 0.5624 - 15s/epoch - 58ms/step
# Epoch 183/200
# 252/252 - 15s - loss: 0.1976 - accuracy: 0.9379 - val_loss: 3.8669 - val_accuracy: 0.5591 - 15s/epoch - 58ms/step
# Epoch 184/200
# 252/252 - 15s - loss: 0.1992 - accuracy: 0.9368 - val_loss: 3.8978 - val_accuracy: 0.5688 - 15s/epoch - 58ms/step
# Epoch 185/200
# 252/252 - 14s - loss: 0.1950 - accuracy: 0.9379 - val_loss: 3.8434 - val_accuracy: 0.5775 - 14s/epoch - 57ms/step
# Epoch 186/200
# 252/252 - 14s - loss: 0.2012 - accuracy: 0.9366 - val_loss: 3.8381 - val_accuracy: 0.5713 - 14s/epoch - 57ms/step
# Epoch 187/200
# 252/252 - 14s - loss: 0.1863 - accuracy: 0.9402 - val_loss: 3.9298 - val_accuracy: 0.5606 - 14s/epoch - 57ms/step
# Epoch 188/200
# 252/252 - 14s - loss: 0.1777 - accuracy: 0.9430 - val_loss: 4.0976 - val_accuracy: 0.5639 - 14s/epoch - 58ms/step
# Epoch 189/200
# 252/252 - 14s - loss: 0.1918 - accuracy: 0.9382 - val_loss: 3.9648 - val_accuracy: 0.5634 - 14s/epoch - 57ms/step
# Epoch 190/200
# 252/252 - 14s - loss: 0.2056 - accuracy: 0.9343 - val_loss: 3.9525 - val_accuracy: 0.5668 - 14s/epoch - 57ms/step
# Epoch 191/200
# 252/252 - 14s - loss: 0.1953 - accuracy: 0.9398 - val_loss: 4.0184 - val_accuracy: 0.5636 - 14s/epoch - 57ms/step
# Epoch 192/200
# 252/252 - 14s - loss: 0.1783 - accuracy: 0.9435 - val_loss: 4.0447 - val_accuracy: 0.5644 - 14s/epoch - 57ms/step
# Epoch 193/200
# 252/252 - 14s - loss: 0.1780 - accuracy: 0.9438 - val_loss: 4.0223 - val_accuracy: 0.5624 - 14s/epoch - 57ms/step
# Epoch 194/200
# 252/252 - 15s - loss: 0.1845 - accuracy: 0.9398 - val_loss: 3.9398 - val_accuracy: 0.5753 - 15s/epoch - 58ms/step
# Epoch 195/200
# 252/252 - 14s - loss: 0.1912 - accuracy: 0.9412 - val_loss: 4.0305 - val_accuracy: 0.5649 - 14s/epoch - 58ms/step
# Epoch 196/200
# 252/252 - 14s - loss: 0.1750 - accuracy: 0.9433 - val_loss: 3.9798 - val_accuracy: 0.5726 - 14s/epoch - 58ms/step
# Epoch 197/200
# 252/252 - 14s - loss: 0.1855 - accuracy: 0.9387 - val_loss: 4.0524 - val_accuracy: 0.5636 - 14s/epoch - 57ms/step
# Epoch 198/200
# 252/252 - 14s - loss: 0.1949 - accuracy: 0.9376 - val_loss: 4.0358 - val_accuracy: 0.5696 - 14s/epoch - 57ms/step
# Epoch 199/200
# 252/252 - 14s - loss: 0.1705 - accuracy: 0.9455 - val_loss: 4.0446 - val_accuracy: 0.5703 - 14s/epoch - 57ms/step
# Epoch 200/200
# 252/252 - 15s - loss: 0.1703 - accuracy: 0.9450 - val_loss: 3.9880 - val_accuracy: 0.5659 - 15s/epoch - 58ms/step
# 126/126 [==============================] - 1s 11ms/step - loss: 3.9880 - accuracy: 0.5659
# 3.987950325012207
# 0.5658548474311829
# (1, 28, 28, 1)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-462084dc51ea> in <module>()
#     167 filter_num=0
#     168
# --> 169 activations = get_featuremaps(model, int(layer_num),test_image)
#     170
#     171 print (np.shape(activations))
#
# <ipython-input-3-462084dc51ea> in get_featuremaps(model, layer_idx, X_batch)
#     160 print (test_image.shape)
#     161 def get_featuremaps(model, layer_idx, X_batch):
# --> 162         get_activations = K.function([model.layers[0].input, K.learning_phase()],[model.layers[layer_idx].output,])
#     163         activations = get_activations([X_batch,0])
#     164         return activations
#
# /usr/local/lib/python3.7/dist-packages/keras/backend.py in function(inputs, outputs, updates, name, **kwargs)
#    4227     from keras import models  # pylint: disable=g-import-not-at-top
#    4228     from keras.utils import tf_utils  # pylint: disable=g-import-not-at-top
# -> 4229     model = models.Model(inputs=inputs, outputs=outputs)
#    4230
#    4231     wrap_outputs = isinstance(outputs, list) and len(outputs) == 1
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/tracking/base.py in _method_wrapper(self, *args, **kwargs)
#     528     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     529     try:
# --> 530       result = method(self, *args, **kwargs)
#     531     finally:
#     532       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py in __init__(self, inputs, outputs, name, trainable, **kwargs)
#     142     if tf.compat.v1.executing_eagerly_outside_functions():
#     143       if not all([functional_utils.is_input_keras_tensor(t)
# --> 144                   for t in tf.nest.flatten(inputs)]):
#     145         inputs, outputs = functional_utils.clone_graph_nodes(inputs, outputs)
#     146     self._init_graph_network(inputs, outputs)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py in <listcomp>(.0)
#     142     if tf.compat.v1.executing_eagerly_outside_functions():
#     143       if not all([functional_utils.is_input_keras_tensor(t)
# --> 144                   for t in tf.nest.flatten(inputs)]):
#     145         inputs, outputs = functional_utils.clone_graph_nodes(inputs, outputs)
#     146     self._init_graph_network(inputs, outputs)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional_utils.py in is_input_keras_tensor(tensor)
#      45   """
#      46   if not node_module.is_keras_tensor(tensor):
# ---> 47     raise ValueError(_KERAS_TENSOR_TYPE_CHECK_ERROR_MSG.format(tensor))
#      48   return tensor.node.is_input
#      49
#
# ValueError: Found unexpected instance while processing input tensors for keras functional model. Expecting KerasTensor which is from tf.keras.Input() or output from keras layer call(). Got: 0
